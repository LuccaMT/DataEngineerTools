# %% [markdown]
# # Introduction
#
# [Scrapy](https://scrapy.org/) est un framework permettant de crawler des
# sites web et d'en extraire les données de façon structurée.
#
# ## Installation
#
# [Scrapy](https://scrapy.org/) ne fait pas partie de la distribution par
# défaut de Python et doit être installé manuellement. Ici, le package est
# déjà installé grâce à Pipenv.
#
# Si vous avez besoin de l'installer dans un autre cadre.
#
# -   Avec **Pipenv** : `pipenv install scrapy==2.11.2`
#
# **Vérifiez que vous avez bien activé votre environnement virtuel Python !!**

# %%
# !which python
# Out:
# 'which' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %%
import scrapy

# %% [markdown]
# ## Architecture
#
# [Scrapy](https://scrapy.org/) est un framework comportant plusieurs
# composants.
#
# <img src="images/architecture.png" alt="image" class="align-center" />
#
# L'ensemble du processus est contrôlé par l'**engine** (les termes anglo
# saxons ont été retenus pour un meilleur référencement dans la
# [documentation officielle](https://docs.scrapy.org/en/latest/)).
#
# Le framework est articulé avec plusieurs composants qui gèrent chacun un
# rôle différent. Nous allons les détailler.
#
# -   Les **Spiders** : permettent de naviguer sur un site et de
#     référencer les règles d'extraction de la donnée.
# -   Les **Pipelines** : font le lien entre la donnée brute et des objets
#     structurés
# -   Les **Middlewares** : permettent d'effectuer des transformations sur
#     les objets ou sur les requêtes exécutées par l'engine.
# -   Le **Scheduler** : gère l'ordre et le timing des requêtes
#     effectuées.
#
# ## Fonctionnement
#
# [Scrapy](https://scrapy.org/) est entièrement organisé autour d'un
# composant central : l'*engine*.
#
# Le rôle de l'*engine* est de contrôler le flux de données entre les
# différents composants du système.
#
# 1.  En particulier, il est chargé de récupérer les *requests* définies
#     dans les *spiders*
# 2.  Ces *requests* sont ensuite fournies au *scheduler* qui se charge de
#     leur ordonnancement
# 3.  Les *requests* sont présentées selon cet ordonnancement à
#     l'*engine*...
# 4.  ... qui les transmet au *downloader*
# 5.  Le *downloader* effectue la *request* et transmet la *response* (le
#     contenu de la page web) à l'*engine*...
# 6.  ... puis l'envoie au *spider* pour traitement
# 7.  Le *spider* génére des *items* qui sont transmis à l'*engine*
# 8.  Les *items* sont ensuite poussés dans un pipeline pour nettoyage,
#     validation et stockage
#
# Ce processus est répété jusqu'à épuisement des requêtes.
#
# [Scrapy](https://scrapy.org/) est un [framework orienté
# événements](https://en.wikipedia.org/wiki/Event-driven_architecture)
# (basé sur [Twisted](https://twistedmatrix.com/)) permettant une
# programmation asynchrone (non bloquante). C'est particulièrement
# intéressant dans les opérations de scraping, puisque **le programme
# n'attend pas le résultat d'une requête pour en lancer une autre**.
#
# En effet, lorsque l'on sollicite une ressource (requête réseau, système
# de fichier, etc.) en mode bloquant, l'exécution du programme est
# suspendue le temps que la transaction avec la ressource se termine (par
# exemple le temps qu'une page web soit complètement téléchargée).
# L'intérêt de faire des appels non bloquants, c'est que l'on peut gérer
# de multiples téléchargements en parallèle, et que le programme peut
# continuer à tourner pendant ce temps.

# %% [markdown]
# # Un scraping élémentaire
#
# Avant de rentrer dans les détails du framework, nous allons mettre en
# oeuvre un premier script permettant de récupérer l'information présente
# sur [la page web](http://evene.lefigaro.fr/citations/winston-churchill)
# recensant les citations de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill).
#
# **Exercice**
#
# Examiner le code source de cette page avec l'inspecteur de votre
# navigateur. Identifier les éléments contenant l'information recherchée,
# ici la chaîne de caractères contenant la citation proprement dite.
#
# ## Le code source
#
# Le code utilisé est le suivant:

# %%
# %load citations_churchill_spider1.py
import scrapy


class ChurchillQuotesSpider(scrapy.Spider):
    name = "citations de Churchill"
    start_urls = ["http://evene.lefigaro.fr/citations/winston-churchill", ]

    def parse(self, response):
        for cit in response.xpath('//div[@class="figsco__quote__text"]'):
            text_value = cit.xpath('a/text()').extract_first()
            yield {'text': text_value}

# %% [markdown]
# ## Le fonctionnement
#
# Le fonctionnement est le suivant:
#
# -   On importe le module scrapy (2)
# -   et on définit une sous classe de `scrapy.Spider` (4)
# -   la variable `start_urls` contient la liste des pages à scraper (6)
# -   On redéfinit la méthode $parse$ dont la signature est définie dans
#     la classe mère (8)
# -   L'objet
#     [response](https://docs.scrapy.org/en/latest/topics/request-response.html#response-objects)
#     représente la réponse à la requête HTTP (l'attribut $text$ permet
#     d'accéder à son contenu). On recherche ensuite tous les containers
#     `<div>` identifiés dans l'exercice précédent. Ici la page est
#     particulièrement bien structurée et les citations disposent de leur
#     propre container, identifié par l'attribut `class` de valeur
#     `figsco__quote__text`. La sélection se fait par une expression
#     [XPath](https://en.wikipedia.org/wiki/XPath), un langage de
#     sélection de noeud dans un document XML (9). En langage naturel, la
#     requête pourrait se formuler : "On recherche tous les containers
#     `<div>` dont la valeur de l'attribut `class` est égal à
#     `figsco__quote__text`".
# -   Pour chaque résultat, on construit un dictionnaire dont la clé est
#     `text` et la valeur le contenu du lien `<a>`. Ce résultat est fourni
#     par un générateur ($yield$) (11).
#
# On lance le scraping depuis un terminal (attention, ici on ne lance pas la cellule du jupyter notebook mais vraiment le script contenu dans le ifchier citations_churchill_spider1.py):

# %%
# !scrapy runspider citations_churchill_spider1.py
# Out:
# 2025-11-25 15:25:19 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: scrapybot)
# 2025-11-25 15:25:19 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.11.7, cssselect 1.3.0, parsel 1.10.0, w3lib 2.3.1, Twisted 25.5.0, Python 3.12.12 (main, Oct 31 2025, 23:00:21) [MSC v.1944 64 bit (AMD64)], pyOpenSSL 25.3.0 (OpenSSL 3.5.4 30 Sep 2025), cryptography 46.0.3, Platform Windows-11-10.0.26200-SP0
# 2025-11-25 15:25:19 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-11-25 15:25:19 [py.warnings] WARNING: C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2025-11-25 15:25:19 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2025-11-25 15:25:19 [scrapy.extensions.telnet] INFO: Telnet Password: ea17e72091af2fc4
# 2025-11-25 15:25:19 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2025-11-25 15:25:19 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# 2025-11-25 15:25:19 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-11-25 15:25:19 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-11-25 15:25:19 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-11-25 15:25:19 [scrapy.core.engine] INFO: Spider opened
# 2025-11-25 15:25:19 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-11-25 15:25:19 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-11-25 15:25:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.”'}
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Un conciliateur c'est quelqu'un qui nourrit un crocodile en espérant qu'il sera le dernier à être mangé.”"}
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Il est une bonne chose de lire des livres de citations, car les citations lorsqu’elles sont gravées dans la mémoire vous donnent de bonnes pensées.”'}
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Je suis toujours prêt à apprendre, bien que je n'aime pas toujours qu'on me donne des leçons.”"}
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“C'est une belle chose d'être honnête, mais il est également important d'avoir raison.”"}
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“J’ai retiré plus de choses de l’alcool que l’alcool ne m’en a retirées.”'}
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Pour s'améliorer, il faut changer. Donc, pour être parfait, il faut avoir changé souvent.”"}
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“On considère le chef d'entreprise comme un homme à abattre, ou une vache à traire. Peu voient en lui le cheval qui tire le char.”"}
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“En Angleterre, tout est permis, sauf ce qui est interdit. En Allemagne, tout est interdit, sauf ce qui est permis. En France, tout est permis, même ce qui est interdit. En U.R.S.S., tout est interdit, même ce qui est permis.”'}
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“On vit de ce que l’on obtient.\rOn construit sa vie sur ce que l’on donne.”'}
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Si deux hommes ont toujours la même opinion, l'un d'eux est de trop.”"}
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Plus vous saurez regarder loin dans le passé, plus vous verrez loin dans le futur.”'}
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“L’Angleterre s’écroule dans l’ordre, et la France se relève dans le désordre.”'}
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“En avalant les méchantes paroles qu'on ne profère pas, on ne s'est jamais abîmé l'estomac.”"}
# 2025-11-25 15:25:19 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Comité : Un groupe de personnes incapables de faire quoi que ce soit par elles-mêmes qui décident collectivement que rien ne peut être fait !”'}
# 2025-11-25 15:25:19 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-11-25 15:25:19 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 245,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 14551,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.233025,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 11, 25, 14, 25, 19, 758815, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 83550,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 15,
#  'log_count/DEBUG': 17,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2025, 11, 25, 14, 25, 19, 525790, tzinfo=datetime.timezone.utc)}
# 2025-11-25 15:25:19 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On y trouve des informations sur les paramètres
# utilisés:
#
# ```
# 2018-01-10 17:21:05 [scrapy.utils.log] INFO: Scrapy 1.4.0 started (bot: scrapybot)
# 2018-01-10 17:21:05 [scrapy.utils.log] INFO: Overridden settings: {'SPIDER_LOADER_WARN_ONLY': True}
# ```

# %% [markdown]
# les
# [extensions](https://docs.scrapy.org/en/latest/topics/extensions.html)
# ...:
#
# ```
# 2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# 'scrapy.extensions.telnet.TelnetConsole',
# 'scrapy.extensions.logstats.LogStats']
# ```

# %% [markdown]
# [Les composants middleware
# downloader](https://docs.scrapy.org/en/latest/topics/downloader-middleware.html)
# ... :
#
# ```
# 2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
# 'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
# 'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
# 'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
# 'scrapy.downloadermiddlewares.retry.RetryMiddleware',
# 'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
# 'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
# 'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
# 'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
# 'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
# 'scrapy.downloadermiddlewares.stats.DownloaderStats']
# ```

# %% [markdown]
# Idem pour [les composants middleware
# spider](https://docs.scrapy.org/en/latest/topics/spider-middleware.html)
# ...:
#
# ```
# 2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
# 'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
# 'scrapy.spidermiddlewares.referer.RefererMiddleware',
# 'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
# 'scrapy.spidermiddlewares.depth.DepthMiddleware']
# ```

# %% [markdown]
# Aucun
# [pipeline](https://docs.scrapy.org/en/latest/topics/item-pipeline.html)
# n'est activé :
#
# ```
# 2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# ```

# %% [markdown]
# **Exercice**
#
# Identifier la position des [composants middleware
# downloader](https://docs.scrapy.org/en/latest/topics/downloader-middleware.html),
# des [composants middleware
# spider](https://docs.scrapy.org/en/latest/topics/spider-middleware.html)
# et du
# [pipeline](https://docs.scrapy.org/en/latest/topics/item-pipeline.html)
# dans $l'architecture <Introduction>$
#
# L'exécution du scraping proprement dit débute :
# ```
# 2018-01-10 17:21:05 [scrapy.core.engine] INFO: Spider opened
# 2018-01-10 17:21:05 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-01-10 17:21:05 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# ```

# %% [markdown]
# La première URL est poussée par le scheduler:
# ```
# 2018-01-10 17:21:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)
# ```

# %% [markdown]
# ## Les résultats
#
# Les résultats sont fournis par le générateur défini dans la méthode
# $parse$ dans un dictionnaire. Ils contiennent le texte des citations
# dans la valeur de la clé `text` :
# ```
# 2018-01-10 17:21:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': '“Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.”'}
# 2018-01-10 17:21:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': "Faire le bien, éviter le mal, c'est ça le paradis."}
# ```

# %% [markdown]
# ## Les statistiques
#
# Une fois le scraping effectué, quelques statistiques sont affichées sur
# le terminal:
# ```
# 2018-01-10 17:21:05 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-01-10 17:21:05 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 242,
# 'downloader/request_count': 1,
# 'downloader/request_method_count/GET': 1,
# 'downloader/response_bytes': 17435,
# 'downloader/response_count': 1,
# 'downloader/response_status_count/200': 1,
# 'finish_reason': 'finished',
# 'finish_time': datetime.datetime(2018, 1, 10, 16, 21, 5, 858347),
# 'item_scraped_count': 16,
# 'log_count/DEBUG': 18,
# 'log_count/INFO': 7,
# 'response_received_count': 1,
# 'scheduler/dequeued': 1,
# 'scheduler/dequeued/memory': 1,
# 'scheduler/enqueued': 1,
# 'scheduler/enqueued/memory': 1,
# 'start_time': datetime.datetime(2018, 1, 10, 16, 21, 5, 645347)}
# 2018-01-10 17:21:05 [scrapy.core.engine] INFO: Spider closed (finished)
# ```

# %% [markdown]
# On observe notamment que notre code permet de récupérer la taille de la
# page web (17435 bytes), le temps d'exécution à partir des valeurs
# `finish_time` et `start_time`, le nombre d'items scrapés (16), etc...
#
# **Exercice**
#
# Les citations extraites sont elles toutes de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill) ? Il sera
# peut être nécessaire de modifier le sélecteur XPath. Nous verrons ça
# lorsque il faudra récupérer les données relative à l'auteur.

# %% [markdown]
# ## Modifier les données
#
# Il est parfois nécessaire de faire un traitement sur les données
# scrapées, pour ajouter ou retirer de l'information.
#
# **Exercice**
#
# Retirer les caractères `“` et `”` qui délimitent la citation. Ces
# caractères sont identifiés en Unicode comme [LEFT DOUBLE QUOTATION
# MARK](http://www.fileformat.info/info/unicode/char/201c/index.htm) et
# [RIGHT DOUBLE QUOTATION
# MARK](http://www.fileformat.info/info/unicode/char/201d/index.htm).
#
# Attention, ici il faut bien modifier directement le script `citations_churchill_spider1.py` et lancer dans une cellule ou votre terminal la commande utilisée précédemment : `scrapy runspider citations_churchill_spider1.py`

# %%
# !scrapy runspider citations_churchill_spider2.py
# Out:
# 2025-11-25 15:25:20 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: scrapybot)
# 2025-11-25 15:25:20 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.11.7, cssselect 1.3.0, parsel 1.10.0, w3lib 2.3.1, Twisted 25.5.0, Python 3.12.12 (main, Oct 31 2025, 23:00:21) [MSC v.1944 64 bit (AMD64)], pyOpenSSL 25.3.0 (OpenSSL 3.5.4 30 Sep 2025), cryptography 46.0.3, Platform Windows-11-10.0.26200-SP0
# 2025-11-25 15:25:20 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-11-25 15:25:20 [py.warnings] WARNING: C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2025-11-25 15:25:20 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2025-11-25 15:25:20 [scrapy.extensions.telnet] INFO: Telnet Password: 2c2493f92d9bca07
# 2025-11-25 15:25:21 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2025-11-25 15:25:21 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# 2025-11-25 15:25:21 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-11-25 15:25:21 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-11-25 15:25:21 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-11-25 15:25:21 [scrapy.core.engine] INFO: Spider opened
# 2025-11-25 15:25:21 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-11-25 15:25:21 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-11-25 15:25:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.”'}
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Un conciliateur c'est quelqu'un qui nourrit un crocodile en espérant qu'il sera le dernier à être mangé.”"}
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Il est une bonne chose de lire des livres de citations, car les citations lorsqu’elles sont gravées dans la mémoire vous donnent de bonnes pensées.”'}
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Je suis toujours prêt à apprendre, bien que je n'aime pas toujours qu'on me donne des leçons.”"}
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“C'est une belle chose d'être honnête, mais il est également important d'avoir raison.”"}
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“J’ai retiré plus de choses de l’alcool que l’alcool ne m’en a retirées.”'}
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Pour s'améliorer, il faut changer. Donc, pour être parfait, il faut avoir changé souvent.”"}
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“On considère le chef d'entreprise comme un homme à abattre, ou une vache à traire. Peu voient en lui le cheval qui tire le char.”"}
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“En Angleterre, tout est permis, sauf ce qui est interdit. En Allemagne, tout est interdit, sauf ce qui est permis. En France, tout est permis, même ce qui est interdit. En U.R.S.S., tout est interdit, même ce qui est permis.”'}
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“On vit de ce que l’on obtient.\rOn construit sa vie sur ce que l’on donne.”'}
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Si deux hommes ont toujours la même opinion, l'un d'eux est de trop.”"}
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Plus vous saurez regarder loin dans le passé, plus vous verrez loin dans le futur.”'}
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“L’Angleterre s’écroule dans l’ordre, et la France se relève dans le désordre.”'}
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“En avalant les méchantes paroles qu'on ne profère pas, on ne s'est jamais abîmé l'estomac.”"}
# 2025-11-25 15:25:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Comité : Un groupe de personnes incapables de faire quoi que ce soit par elles-mêmes qui décident collectivement que rien ne peut être fait !”'}
# 2025-11-25 15:25:21 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-11-25 15:25:21 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 245,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 14551,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.189758,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 11, 25, 14, 25, 21, 517728, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 83550,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 15,
#  'log_count/DEBUG': 17,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2025, 11, 25, 14, 25, 21, 327970, tzinfo=datetime.timezone.utc)}
# 2025-11-25 15:25:21 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## Plus de données
#
# Il est souvent nécessaire de récupérer plusieurs informations relatives
# à un même item. Dans cet exemple, il est judicieux d'associer à la
# citation le nom de son auteur, en allant chercher cette information au
# plus près du texte lui même.
#
# **Exercice**
#
# Examiner le code source de la page web et identifier la structuration de
# la donnée associée à l'auteur. En déduire l'expression XPath permettant
# de la récupérer. S'assurer que seules les citations de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill) sont
# extraites. Ajouter une clé `author` au dictionnaire retourné par le
# $yield$ dont la valeur est précisément la chaîne de caractères contenant
# l'auteur.
#
# Un exemple de dictionnaire retourné:
# ```
# {
#     'text': "Si deux hommes ont toujours la même opinion, l'un d'eux est de trop.",
#     'author': 'Winston Churchill'
# }
# ```

# %% [markdown]
# si vous voulez stocker les données scrapées dans un fichier vous pouvez grâce à :
# ```
# scrapy runspider citations_churchill_spider1.py -o data/citation.json -t json
# ```

# %%
# !scrapy runspider citations_churchill_spider3.py -o data/citation.json -t json
# Out:
# C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\commands\__init__.py:171: ScrapyDeprecationWarning: The -t/--output-format command line option is deprecated in favor of specifying the output format within the output URI using the -o/--output or the -O/--overwrite-output option (i.e. -o/-O <URI>:<FORMAT>). See the documentation of the -o or -O option or the following examples for more information. Examples working in the tutorial: scrapy crawl quotes -o quotes.csv:csv   or   scrapy crawl quotes -O quotes.json:json
#   feeds = feed_process_params_from_cli(
# 2025-11-25 15:25:22 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: scrapybot)
# 2025-11-25 15:25:22 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.11.7, cssselect 1.3.0, parsel 1.10.0, w3lib 2.3.1, Twisted 25.5.0, Python 3.12.12 (main, Oct 31 2025, 23:00:21) [MSC v.1944 64 bit (AMD64)], pyOpenSSL 25.3.0 (OpenSSL 3.5.4 30 Sep 2025), cryptography 46.0.3, Platform Windows-11-10.0.26200-SP0
# 2025-11-25 15:25:22 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-11-25 15:25:22 [py.warnings] WARNING: C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2025-11-25 15:25:22 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2025-11-25 15:25:22 [scrapy.extensions.telnet] INFO: Telnet Password: fe0c6d05b4717ef2
# 2025-11-25 15:25:22 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-11-25 15:25:22 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# 2025-11-25 15:25:22 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-11-25 15:25:22 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-11-25 15:25:22 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-11-25 15:25:22 [scrapy.core.engine] INFO: Spider opened
# 2025-11-25 15:25:22 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-11-25 15:25:22 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-11-25 15:25:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)
# 2025-11-25 15:25:23 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-11-25 15:25:23 [scrapy.extensions.feedexport] INFO: Stored json feed (0 items) in: data/citation.json
# 2025-11-25 15:25:23 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 245,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 14551,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.242498,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 11, 25, 14, 25, 23, 215196, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 83550,
#  'httpcompression/response_count': 1,
#  'log_count/DEBUG': 2,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2025, 11, 25, 14, 25, 22, 972698, tzinfo=datetime.timezone.utc)}
# 2025-11-25 15:25:23 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# # Votre premier projet
#
#
# Dans un premier temps vous devez créer un projet Scrapy avec la commande
# :

# %%
# !scrapy startproject monprojet
# Out:
# Error: scrapy.cfg already exists in C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\2Scrapy\monprojet

# %% [markdown]
# Cette commande va créer un dossier `monprojet` contenant les éléments
# suivants correspondant au squelette :
#
# ```
# newscrawler/
#     scrapy.cfg            # Options de déploiement
#
#     newscrawler/             # Le module Python contenant les informations
#         __init__.py
#
#         items.py          # Fichier contenant les items
#
#         middlewares.py    # Fichier contenant les middlewares
#
#         pipelines.py      # Fichier contenant les pipelines
#
#         settings.py       # Fichier contenant les paramètres du projet
#
#         spiders/          # Dossier contenant toutes les spiders
#             __init__.py
# ```

# %% [markdown]
# **Attention, à partir de maintenant vous créerez et modifierez les fichiers python dans votre projet scrapy et non pas dans les cellules jupyter qui sont là juste pour l'exemple**
#
# Pour la suite, un projet scrapy du nom de `newscrawler` est présent dans le repo pour vous guider, vous pouvez vous en inspirer pour implémenter vos propres spiders mais n'hésitez pas à explorer les méthodes que scrapy offre depuis la documentation.

# %% [markdown]
# # Votre première Spider
#
# Une Spider est une classe Scrapy qui permet de mettre en place toute
# l'architecture complexe vue dans l'introduction. Pour définir une
# spider, il vous faut hériter de la classe $scrapy.Spider$. La seule
# chose à faire est de définir la première requête à effectuer et comment
# suivre les liens. La Spider s'arrêtera lorsqu'elle aura parcouru tous
# les liens qu'on lui a demandé de suivre.
#
# Pour créer une Spider on utilise la syntaxe:

# %%
# !scrapy genspider <SPIDER_NAME> <DOMAIN_NAME>
# Out:
# < �tait inattendu.

# %% [markdown]
# Par exemple,

# %%
# !cd newscrawler && scrapy genspider books books.toscrape.com
# Out:
# Spider 'books' already exists in module:
#   newscrawler.spiders.books

# %% [markdown]
# Cette commande permet de créer une spider appelée `lemonde` pour scraper
# le domaine `lemonde.fr`. Cela crée le fichier Python
# `spiders/lemonde.py` suivant :

# %%
# %load newscrawler/newscrawler/spiders/lemonde.py
import scrapy


class BooksSpider(scrapy.Spider):
    name = 'books'
    allowed_domains = ['books.toscrape.com']
    start_urls = ['http://books.toscrape.com/']

    def parse(self, response):
        pass

# %% [markdown]
# Une bonne pratique pour commencer à développer une Spider est de passer
# par l'interface Shell proposée par Scrapy. Elle permet de récupérer un
# objet `Response` et de tester les méthodes de récupération des données.

# %% [markdown]
# ### ATTENTION : Les commandes scrapy shell doivent être lancées dans un terminal et non dans des cellules jupyter

# %% [markdown]
# `$ scrapy shell 'http://lemonde.fr'`

# %% [markdown]
# Pour les utilisateurs de windows il vous faut mettre des doubles quotes
# :
# ```
# scrapy shell "http://lemonde.fr"
# ```

# %% [markdown]
# Scrapy lance un kernel Python
#
# Grâce à cette interface, vous avez accès à plusieurs objets comme la
# `Response`, la `Request`, la `Spider` par exemple. Vous pouvez aussi
# exécuter `view(response)` pour afficher ce que Scrapy récupère dans un
# navigateur.
#
# Voici quelques exemples de commandes que vous pouvez faire dans le scrapy shell :
# ```
# In [1]: response
# Out[1]: <200 https://www.lemonde.fr/>
#
# In [3]: request
# Out[3]: <GET https://www.lemonde.fr/>
#
# In [4]: type(request)
# Out[4]: scrapy.http.request.Request
#
# In [5]: spider
# Out[5]: <LemondeSpider 'lemonde' at 0x1080fccc0>
#
# In [6]: type(spider)
# Out[6]: monprojet.spiders.lemonde.LeMondeSpider
# ```

# %% [markdown]
# Ici on voit que la Spider est une instance de LemondeSpider. Lorsqu'on
# lance le $scrapy shell$ scrapy va chercher dans les spiders si une
# correspond au lien passé en paramètre, si oui , il l'utilise sinon une
# $DefaultSpider$ est instanciée.
#
# ## Vos premières requêtes
#
# On peut commencer à regarder comment extraire les données de la page web
# en utilisant le langage de requêtes proposé par Scrapy. Il existe deux
# types de requêtes : les requêtes `css` et `xpath`. Les requêtes `xpath`
# sont plus complexes mais plus puissantes que les requêtes `css`. Dans le
# cadre de ce tutorial, nous allons uniquement aborder les requêtes `css`,
# elles nous suffiront pour extraire les données dont nous avons besoin
# (en interne, Scrapy transforme les requêtes `css`en requêtes `xpath`.
#
# Que ce soit les requêtes `css` ou `xpath`, elles crééent des sélecteurs
# de différents types. Quelques exemples :
#
# Pour récupérer le titre d'une page :
# ```
# In [1]: response.css('title')
# Out[1]: [<Selector xpath='descendant-or-self::title' data='<title>Le Monde.fr - Actualités et Infos'>]
# ```

# %% [markdown]
# On récupère une liste de sélecteurs correspondant à la requête `css`
# appelée. La requête précédente était unique, d'autres requêtes moins
# restrictives permettent de récupérer plusieurs résultats. Par exemple
# pour rechercher l'ensemble des liens présents sur la page, on va
# rechercher les balises HTML `<a></a>`
#
# ```
# In [5]: response.css("a")[0:10]
# Out[5]:
# [<Selector xpath='descendant-or-self::a' data='<a target="_blank" data-target="jelec-he'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/"> <div class="logo__lemonde l'>,
# <Selector xpath='descendant-or-self::a' data='<a href="https://secure.lemonde.fr/sfuse'>,
# <Selector xpath='descendant-or-self::a' data='<a href="https://abo.lemonde.fr/#xtor=CS'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/" class="Burger__right-arrow j'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/" class="Burger__right-arrow j'>,
# <Selector xpath='descendant-or-self::a' data='<a href="#" class="js-dropdown Burger__r'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/mouvement-des-gilets-jaunes/" '>,
# <Selector xpath='descendant-or-self::a' data='<a href="/carlos-ghosn/" data-suggestion'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/implant-files/" data-suggestio'>]
# ```

# %% [markdown]
# Pour récupérer le texte contenu dans les balises, on passe le paramètre
# `<TAG>::text`. Par exemple :
#
# ```
# In [6]: response.css("title::text")
# Out[6]: [<Selector xpath='descendant-or-self::title/text()' data='Le Monde.fr - Actualités et Infos en Fra'>]
# ```

# %% [markdown]
# ### Exercice
#
# Comparer les résultats des deux requêtes `response.css('title')` et
# `response.css('title::text')`.
#
# Maintenant pour extraire les données des selecteurs on utilise l'une des
# deux méthodes suivantes :
# - `extract()` permet de récupérer une liste
# des données extraites de tous les sélecteurs
# - `extract_first()` permet
# de récupérer une `String` provenant du premier sélecteur de la liste.
#
#
# ```
# In [7]: response.css('title::text').extract_first()
# Out[7]: 'Le Monde.fr - Actualités et Infos en France et dans le monde'
# ```

# %% [markdown]
# On peut récupérer un attribut d'une balise avec la syntaxe
# `<TAG>::attr(<ATTRIBUTE_NAME>)` :
#
# Par exemple, les liens sont contenus dans un attribut `href`:
#
# ```
# In [9]: response.css('a::attr(href)')[0:10]
# Out[9]:
# [<Selector xpath='descendant-or-self::a/@href' data='https://journal.lemonde.fr'>,
# <Selector xpath='descendant-or-self::a/@href' data='/'>,
# <Selector xpath='descendant-or-self::a/@href' data='https://secure.lemonde.fr/sfuser/connexi'>,
# <Selector xpath='descendant-or-self::a/@href' data='https://abo.lemonde.fr/#xtor=CS1-454[CTA'>,
# <Selector xpath='descendant-or-self::a/@href' data='/'>,
# <Selector xpath='descendant-or-self::a/@href' data='/'>,
# <Selector xpath='descendant-or-self::a/@href' data='#'>,
# <Selector xpath='descendant-or-self::a/@href' data='/mouvement-des-gilets-jaunes/'>,
# <Selector xpath='descendant-or-self::a/@href' data='/carlos-ghosn/'>,
# <Selector xpath='descendant-or-self::a/@href' data='/implant-files/'>]
# ```

# %% [markdown]
# Comme vu précédemment, si on veut récupérer la liste des liens de la page on applique la méthode $extract()$
#
# ```
# In [11]: response.css('a::attr(href)').extract()[0:10]
# Out[11]:
# ['https://journal.lemonde.fr',
# '/',
# 'https://secure.lemonde.fr/sfuser/connexion',
# 'https://abo.lemonde.fr/#xtor=CS1-454[CTA_LMFR]-[HEADER]-5-[Home]',
# '/',
# '/',
# '#',
# '/mouvement-des-gilets-jaunes/',
# '/carlos-ghosn/',
# '/implant-files/']
# ```

# %% [markdown]
# Les liens dans une page HTML sont souvent codés de manière relative par
# rapport à la page courante. La méthode de l'objet `Response` peut être
# utilisée pour recréer l'url complet.
#
# Un exemple sur le 4e élément :
# ```
# In [14]: response.urljoin(response.css('a::attr(href)').extract()[8])
# Out[14]: 'https://www.lemonde.fr/carlos-ghosn/'
# ```

# %% [markdown]
# alors que :
# ```
# In [15]: response.css('a::attr(href)').extract()[8]
# Out[15]: '/carlos-ghosn/'
# ```

# %% [markdown]
# ### Exercice :
#
# Utiliser une liste compréhension pour transformer les 10
# premiers liens relatifs récupérés par la méthode `extract()` en liens
# absolus.
#
# Le résultat doit ressembler à :
# ```
# Out[23]:
# ['https://journal.lemonde.fr',
# 'https://www.lemonde.fr/',
# 'https://secure.lemonde.fr/sfuser/connexion',
# 'https://abo.lemonde.fr/#xtor=CS1-454[CTA_LMFR]-[HEADER]-5-[Home]',
# 'https://www.lemonde.fr/',
# 'https://www.lemonde.fr/',
# 'https://www.lemonde.fr/',
# 'https://www.lemonde.fr/mouvement-des-gilets-jaunes/',
# 'https://www.lemonde.fr/carlos-ghosn/',
# 'https://www.lemonde.fr/implant-files/']
# ```

# %% [markdown]
# ## Des requêtes plus complexes
#
# On peut créer des requêtes plus complexes en utilisant à la fois la
# structuration HTML du document mais également la couche de présentation
# CSS. On utilise l'inspecteur de `Google Chrome` pour identifier le type
# et l'identifiant de la balise contenant les informations.
#
# Il y a au moins deux choses à savoir en `css` :
#
# -   Les `.` représentent les classes
# -   Les `#` représentent les id
#
# On se propose de récupérer toutes les sous-catégories de news dans la
# catégorie **Actualités**. On remarque en utilisant l'inspecteur
# d'élement de Chrome que toutes les catégories sont rangées dans une
# balise avec l'id $#nav-markup$ ensuite dans les classes $Nav__item$.
#
# A partir de cette structure HTML on peut construire la requête suivante
# pour récupérer la barre de navigation:
#
# ```
# In [19]: response.css("#nav-markup")
# Out[19]: [<Selector xpath="descendant-or-self::*[@id = 'nav-markup']" data='<ul id="nav-markup"> <li class="Nav__ite'>]
# ```

# %% [markdown]
# Ensuite pour récupérer les différentes catégories :
#
# ```
# In [24]: response.css('#nav-markup').css('.Nav__item')
# Out[24]:
# [<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item js-burger-to-show N'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item--home Nav'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="/" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="/recherc'>]
# ```

# %% [markdown]
# On veut maintenant retourner tous les liens présents dans cette
# catégorie. On remarque qu'elle apparait à la 4eme position.
# ```
# In [34]: response.css("#nav-markup .Nav__item")[3]
# Out[34]: <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>
# ```

# %% [markdown]
# Maintenant pour récupérer tous les liens, on peut chainer les requêtes.
# On accède alors à toutes les balises $a$.
#
# ```
# In [35]: response.css("#nav-markup .Nav__item")[3].css("a")
# Out[35]:
# [<Selector xpath='descendant-or-self::a' data='<a href="#" class="js-dropdown Burger__r'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/mouvement-des-gilets-jaunes/" '>,
# <Selector xpath='descendant-or-self::a' data='<a href="/carlos-ghosn/" data-suggestion'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/implant-files/" data-suggestio'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/climat/" data-suggestion>Clima'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/affaire-khashoggi/" data-sugge'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/emmanuel-macron/" data-suggest'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/ukraine/" data-suggestion>Ukra'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/russie/" data-suggestion>Russi'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/referendum-sur-le-brexit/" dat'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/harcelement-sexuel/" data-sugg'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/actualite-en-continu/" data-su'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/international/">International<'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/politique/">Politique</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/societe/">Société</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/les-decodeurs/">Les Décodeurs<'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/sport/">Sport</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/planete/">Planète</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/sciences/">Sciences</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/campus/">M Campus</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/afrique/">Le Monde Afrique</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/pixels/">Pixels</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/actualite-medias/">Médias</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/sante/">Santé</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/big-browser/">Big Browser</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/disparitions/">Disparitions</a'>]
# ```

# %% [markdown]
# Et pour récupérer les titres :
# ```
# In [37]: response.css("#nav-markup .Nav__item")[3].css("a::text").extract()
# Out[37]:
# ['Actualités',
#  'Guerre au Proche-Orient',
#  'Gouvernement Barnier',
#  'Guerre en Ukraine',
#  'Élection présidentielle américaine 2024',
#  '7-Octobre, un an après',
#  'Procès des viols de Mazan',
#  'Donald Trump',
#  'Climat',
#  'Guadeloupe',
#  'Toute l’actualité en continu',
#  'International',
#  'Politique',
#  'Société',
#  'Planète',
#  'Climat',
#  'Le Monde Afrique',
#  'Les Décodeurs',
#  'Sport',
#  'Education',
#  'M Campus',
#  'Santé',
#  'Intimités',
#  'Sciences',
#  'Pixels',
#  'Disparitions',
#  'Le Fil Good',
#  'Podcasts',
#  'Le Monde & Vous']
# ```

# %% [markdown]
# Le shell Scrapy permet de définir la structure des requêtes et de
# s'assurer de la pertinence du résultat retourné. Pour automatiser le
# processus, il faut intégrer cette syntaxe au code Python des modules de
# spider définis dans la structure du projet.

# %% [markdown]
# ## Intégration des requêtes
#
# Le squelette de la classe `LeMondeSpider` généré lors de la création du
# projet doit maintenant être enrichi. Par défaut 3 attributs et une
# méthode `parse()` ont été créés :
#
# -   `name` permet d'identifier sans ambiguïté la spider dans le code.
# -   `allowed_domain` permet de filtrer les requêtes et forcer la spider
#     à rester sur une liste de domaines.
# -   `starts_urls` est la liste des urls d'où la spider va partir pour
#     commencer son scraping.
# -   `parse()` est une méthode héritée de la classe `scrapy.Spider`. Elle
#     doit être redéfinie selon les requêtes que l'on doit effectuer et
#     sera appelée sur l'ensemble des urls contenus dans la liste
#     `starts_urls`.
#
# `parse()` est une fonction `callback` qui sera appelée automatiquement
# sur chaque objet `Response` retourné par la requête. Cette fonction est
# appelée de manière asynchrone. Plusieurs requêtes peuvent ainsi être
# lancées en parallèles sans bloquer le thread principal. L'objet
# `Response` passé en paramètre est le même que celui mis à disposition
# lors de l'exécution du Scrapy Shell.

# %%
def parse(self, response):
    title = response.css('title::text').extract_first()
    all_links = {
        name: response.urljoin(url) for name, url in zip(
            response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
            response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
    }
    yield {
        "title": title,
        "all_links": all_links
    }

# %% [markdown]
# La fonction est un générateur (`yield`) et retourne un dictionnaire
# composé de deux éléments :
#
# -   Le titre de la page;
# -   La liste des liens sortants sous forme de String.
#
# Pour le moment cette spider ne parcourt que la page d'accueil, ce qui
# n'est pas très productif.

# %% [markdown]
# ## Votre premier scraper
#
# Récupérer les données sur un ensemble de pages webs nécessite d'explorer
# en profondeur la structure du site en suivant tout ou partie des liens
# rencontrés.
#
# La spider peut se `balader` sur un site assez efficacement. Il suffit de
# lui indiquer comment faire. Il faut spécifier à Scrapy de générer une
# requête vers une nouvelle page en construisant l'objet `Request`
# correspondant. Ce nouvel objet `Request` est alors inséré dans le
# scheduler de Scrapy. On peut évidemment générer plusieurs `Request`
# simultanément, correspondant par exemple, à différents liens sur la page
# courante. Ils sont insérés séquentiellement dans le scheduler.
#
# Pour cela, on modifie la méthode `parse()` de façon à ce qu'elle retourne
# un objet `Request` pour chaque nouveau lien rencontré. On associe
# également à cet objet une fonction de callback qui déterminera la
# manière dont cette nouvelle page doit être extraite.
#
# Par exemple, pour que la spider continue dans les liens des différentes
# régions (pour l'instant la fonction de callback ne fait rien) :

# %%
# %load newscrawler/newscrawler/spiders/lemonde_v2.py
import scrapy
from scrapy import Request


class BooksSpider(scrapy.Spider):
    name = "booksv2"
    allowed_domains = ["books.toscrape.com"]
    start_urls = ['https://books.toscrape.com']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name: response.urljoin(url) for name, url in zip(
                response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
                response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        yield {
            "title": title,
            "all_links": all_links
        }

# %% [markdown]
# Pour lancer la spider

# %%
# !cd newscrawler && scrapy crawl booksv2
# Out:
# 2025-11-25 15:53:09 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: newscrawler)
# 2025-11-25 15:53:09 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.11.7, cssselect 1.3.0, parsel 1.10.0, w3lib 2.3.1, Twisted 25.5.0, Python 3.12.12 (main, Oct 31 2025, 23:00:21) [MSC v.1944 64 bit (AMD64)], pyOpenSSL 25.3.0 (OpenSSL 3.5.4 30 Sep 2025), cryptography 46.0.3, Platform Windows-11-10.0.26200-SP0
# 2025-11-25 15:53:09 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-11-25 15:53:09 [py.warnings] WARNING: C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2025-11-25 15:53:09 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2025-11-25 15:53:09 [scrapy.extensions.telnet] INFO: Telnet Password: 005538eb1522e5d5
# 2025-11-25 15:53:09 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2025-11-25 15:53:09 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2025-11-25 15:53:10 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-11-25 15:53:10 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-11-25 15:53:10 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-11-25 15:53:10 [scrapy.core.engine] INFO: Spider opened
# 2025-11-25 15:53:10 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-11-25 15:53:10 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-11-25 15:53:10 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://books.toscrape.com/robots.txt> (referer: None)
# 2025-11-25 15:53:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com> (referer: None)
# 2025-11-25 15:53:10 [scrapy.core.scraper] ERROR: Spider error processing <GET https://books.toscrape.com> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#              ^^^^^^^^
#   File "C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#                                                     ^^^^^^^^^^^^
#   File "C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#              ^^^^^^^^
#   File "C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#                        ^^^^^^^^^^^^
#   File "C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#              ^^^^^^^^
#   File "C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#                        ^^^^^^^^^^^^
#   File "C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#              ^^^^^^^^
#   File "C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\booksv2.py", line 14, in parse
#     response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\parsel\selector.py", line 135, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2025-11-25 15:53:10 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-11-25 15:53:10 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 448,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 51883,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 0.814736,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 11, 25, 14, 53, 10, 996545, tzinfo=datetime.timezone.utc),
#  'log_count/DEBUG': 3,
#  'log_count/ERROR': 1,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'spider_exceptions/IndexError': 1,
#  'start_time': datetime.datetime(2025, 11, 25, 14, 53, 10, 181809, tzinfo=datetime.timezone.utc)}
# 2025-11-25 15:53:10 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On veut ensuite *entrer* dans les liens des différentes sous-catégories
# pour récupérer les articles. Pour cela, nous créons une méthode
# `parse_category()` prend en argument un objet `Response` qui sera la
# réponse correspondant aux liens des régions. On peut comme ceci
# traverser un site en définissant des méthodes différentes en fonction du
# type de contenu.
#
# Si la structure du site est plus profonde, on peut empiler autant de
# couches que souhaité.
#
# Quand on arrive sur une page d'une sous-catégorie, on peut vouloir
# récupérer tous les éléments de la page. Pour cela, on réutilise le
# scrapy Shell pour commencer le développement de la nouvelle méthode
# d'extraction.
#
# Par exemple pour la page `https://www.lemonde.fr/international/` :
#
# ```
# scrapy shell 'https://www.lemonde.fr/international/'
# ```

# %% [markdown]
# Le fil des articles est stocké dans une balise avec la classe
# `class=river`.
#
# ```
# In [3]: response.css(".river")
# Out[3]:
# [<Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' fleuve ')]" data='<div class="fleuve">\n   <section>\n      '>,
# <Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' fleuve ')]" data='<div class="fleuve">\n</div>'>]
# ```

# %% [markdown]
# Pour récupérer chacun des articles, il faut adresser les balises
# `<article>` contenues dans le sélecteur:
#
# ```
# In [4]: response.css(".river")[0].css(".teaser")
# Out[4]:
# [<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi mg'>,
# <Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
# <Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
# <Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
# <Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
# <Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
# <Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
# <Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>]
# ```

# %% [markdown]
# Comme précédemment, on peut empiler les sélecteurs `css` pour créer des
# requêtes plus complexes.
#
# Par exemple, pour récupérer tous les titres des différents articles :
#
# ```
# In [8]: response.css(".river")[0].css(".teaser h3::text").extract()
# Out[8]:
# ['«\xa0Le Livre noir de Gaza\xa0»\xa0: décryptage d’une entreprise d’anéantissement',
#  'Au Maroc, la rue se mobilise pour Gaza, le pouvoir maintient sa coopération avec Israël',
#  'La guerre à Gaza ravive de manière inédite le traumatisme des Palestiniens',
#  '7-Octobre\xa0: Benyamin Nétanyahou sous la menace de la justice internationale',
#  'En France, un mouvement propalestinien phagocyté par LFI',
#  'En direct, guerre au\xa0Proche-Orient\xa0: le Hezbollah dit soutenir les efforts du Liban en vue d’un cessez-le-feu',
#  'A Gaza, des destructions agricoles sans précédent qui accroissent le risque de famine',
#  'La Chine veut croire à la reprise de son économie',
#  'Comment «\xa0Le Monde\xa0» a couvert un an de guerre à Gaza',
#  'Guerre Israël-Hamas\xa0: «\xa0L’enjeu consiste à admettre que le salut ne vient jamais de la puissance, uniquement de la négociation\xa0»',
#  'En cartes\xa0: un an de destructions dans la bande de Gaza',
# ...]
# ```

# %% [markdown]
# En HTML les données sont souvent de très mauvaise qualité. Il faut
# définir des méthodes permettant de les nettoyer pour être intégrées dans
# des bases de données.
#
# Par exemple, pour supprimer tous les espaces superflus :

# %%
def clean_spaces(string_):
    if string_ is not None:
        return " ".join(string_.split())

# %% [markdown]
# Pour l'appliquer à tous les titres récupérés, on peut faire une list
# comprehension :
# ```
# In [11]: [clean_spaces(article) for article in response.css(".river")[0].css(".teaser h3::text").extract()]
#
# Out[11]: ['« Le Livre noir de Gaza » : décryptage d’une entreprise d’anéantissement',
#  'Au Maroc, la rue se mobilise pour Gaza, le pouvoir maintient sa coopération avec Israël',
#  'La guerre à Gaza ravive de manière inédite le traumatisme des Palestiniens',
#  '7-Octobre : Benyamin Nétanyahou sous la menace de la justice internationale',
#  'En France, un mouvement propalestinien phagocyté par LFI',
#  'En direct, guerre au Proche-Orient : le Hezbollah dit soutenir les efforts du Liban en vue d’un cessez-le-feu',
#  'A Gaza, des destructions agricoles sans précédent qui accroissent le risque de famine',
#  'La Chine veut croire à la reprise de son économie',
# ...
# ]
#
# ```

# %% [markdown]
# La méthode précédente est intéressante si l'on ne recherche qu'une seule
# information par article.
#
# Par contre si l'on veut récupérer d'autres caractéristiques comme
# l'image ou la description par exemple, il est plus intéressant et plus
# efficace de récupérer l'objet et d'effectuer plusieurs traitements sur
# ce dernier.
#
# Chaque objet retourné par les requêtes `css` est un selecteur avec
# lequel on peut interagir.
#
# Par exemple pour récupérer le titre, l'image et la description :
#
# ```
# In [19]: for article in response.css(".river")[0].css(".teaser"):
#     ...:     title = clean_spaces(article.css('h3::text').extract_first())
#     ...:     image = article.css('img::attr(data-src)').extract_first()
#     ...:     description = article.css('p::text').extract_first()
#     ...:     print(f"Title: {title} \nImage: {image} \nDescription: {description}\n-----")
# ```

# %% [markdown]
# ```
# Title: Le Nobel de médecine honore deux pionniers de la régulation des gènes par de tout petits ARN
# Image: https://img.lemde.fr/2024/10/07/35/0/3000/2000/110/73/60/0/6dafcf3_1728304381125-063-2176426487.jpg
# Description: Les deux lauréats américains, Victor Ambros et Gary Ruvkun, sont récompensés pour l’identification d’une voie de contrôle de l’activité des gènes par des micro-ARN, qui est présente dans toutes les cellules animales et végétales.
# -----
# Title: La position de La France insoumise sur le 7-Octobre, cause de fractures à gauche
# Image: https://img.lemde.fr/2024/10/05/0/0/5304/3536/110/73/60/0/9c38cc7_1728124287163-000-34l44a7.jpg
# Description: « 7-Octobre, un an après ». Alors que Jean-Luc Mélenchon et ses troupes ont érigé la cause palestinienne comme un axe de campagne électorale, les socialistes ont condamné le refus des « insoumis » de qualifier le Hamas de mouvement « terroriste ».
# -----
# ```

# %% [markdown]
# ## Persistence des données
#
# Pour pouvoir stocker les informations que l'on récupère en parcourant un
# site, il faut pouvoir les stocker. On utilise soit de simples
# dictionnaires Python, ou mieux des `scrapy.Item` qui sont des
# dictionnaires améliorés.
#
# Nous allons voir les deux façons de faire. On peut réécrire la méthode
# `parse_category()` pour lui faire retourner un dictionnaire
# correspondant à chaque article rencontré :

# %%
def parse_category(self, response):
    # Extraire les livres de chaque catégorie
    for book in response.css('article.product_pod'):
        yield {
            'title': book.css('h3 a::attr(title)').extract_first(),
            'price': book.css('.price_color::text').extract_first(),
            'availability': book.css('.availability::text').extract()[1].strip(),
            'url': response.urljoin(book.css('h3 a::attr(href)').extract_first())
        }

# %% [markdown]
# Si on combine tout dans la spider :

# %%
import scrapy
from scrapy import Request


class BooksSpider(scrapy.Spider):
    name = "booksv3"
    allowed_domains = ["books.toscrape.com"]
    start_urls = ['https://books.toscrape.com']

    def parse(self, response):
        # Récupérer le titre de la page
        title = response.css('title::text').extract_first()
        
        # Récupérer toutes les catégories de livres
        categories = {}
        for category in response.css('ul.nav-list ul li a'):
            name = category.css('::text').extract_first().strip()
            url = response.urljoin(category.css('::attr(href)').extract_first())
            categories[name] = url
        
        # Suivre les liens des catégories
        for link in categories.values():
            yield Request(link, callback=self.parse_category)
    
    def parse_category(self, response):
        # Extraire les livres de chaque catégorie
        for book in response.css('article.product_pod'):
            yield {
                'title': book.css('h3 a::attr(title)').extract_first(),
                'price': book.css('.price_color::text').extract_first(),
                'availability': book.css('.availability::text').extract()[1].strip(),
                'url': response.urljoin(book.css('h3 a::attr(href)').extract_first())
            }

    def clean_spaces(self, string):
        if string:
            return " ".join(string.split())

# %% [markdown]
# On peut maintenant lancer notre spider avec la commande suivante :
# ```
# scrapy crawl <SPIDER_NAME>
# ```

# %% [markdown]
# `scrapy crawl` permet de démarrer le processus en allant chercher la
# classe `scrapy.Spider` dont l'attribut `name` = &lt;NAME&gt;.
#
# Par exemple, pour la spider `LeMondeSpider` :

# %%
# !cd newscrawler && scrapy crawl booksv3
# Out:
# 2025-11-25 16:01:18 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: newscrawler)
# 2025-11-25 16:01:18 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.11.7, cssselect 1.3.0, parsel 1.10.0, w3lib 2.3.1, Twisted 25.5.0, Python 3.12.12 (main, Oct 31 2025, 23:00:21) [MSC v.1944 64 bit (AMD64)], pyOpenSSL 25.3.0 (OpenSSL 3.5.4 30 Sep 2025), cryptography 46.0.3, Platform Windows-11-10.0.26200-SP0
# 2025-11-25 16:01:18 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-11-25 16:01:18 [py.warnings] WARNING: C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2025-11-25 16:01:18 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2025-11-25 16:01:18 [scrapy.extensions.telnet] INFO: Telnet Password: f912d8a84bc256f4
# 2025-11-25 16:01:19 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2025-11-25 16:01:19 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2025-11-25 16:01:19 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-11-25 16:01:19 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-11-25 16:01:19 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-11-25 16:01:19 [scrapy.core.engine] INFO: Spider opened
# 2025-11-25 16:01:19 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-11-25 16:01:19 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-11-25 16:01:19 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://books.toscrape.com/robots.txt> (referer: None)
# 2025-11-25 16:01:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com> (referer: None)
# 2025-11-25 16:01:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/travel_2/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/crime_51/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/cultural_49/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/erotica_50/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/politics_48/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'title': "It's Only the Himalayas", 'price': '£45.17', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html'}
# 2025-11-25 16:01:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'title': 'Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond', 'price': '£49.43', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html'}
# 2025-11-25 16:01:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'title': 'See America: A Celebration of Our National Parks & Treasured Sites', 'price': '£48.87', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/see-america-a-celebration-of-our-national-parks-treasured-sites_732/index.html'}
# 2025-11-25 16:01:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'title': 'Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel', 'price': '£36.94', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/vagabonding-an-uncommon-guide-to-the-art-of-long-term-world-travel_552/index.html'}
# 2025-11-25 16:01:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'title': 'Under the Tuscan Sun', 'price': '£37.33', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/under-the-tuscan-sun_504/index.html'}
# 2025-11-25 16:01:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'title': 'A Summer In Europe', 'price': '£44.34', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/a-summer-in-europe_458/index.html'}
# 2025-11-25 16:01:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'title': 'The Great Railway Bazaar', 'price': '£30.54', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-great-railway-bazaar_446/index.html'}
# 2025-11-25 16:01:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'title': 'A Year in Provence (Provence #1)', 'price': '£56.88', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/a-year-in-provence-provence-1_421/index.html'}
# 2025-11-25 16:01:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'title': 'The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)', 'price': '£23.21', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-road-to-little-dribbling-adventures-of-an-american-in-britain-notes-from-a-small-island-2_277/index.html'}
# 2025-11-25 16:01:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'title': 'Neither Here nor There: Travels in Europe', 'price': '£38.95', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/neither-here-nor-there-travels-in-europe_198/index.html'}
# 2025-11-25 16:01:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'title': '1,000 Places to See Before You Die', 'price': '£26.08', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/1000-places-to-see-before-you-die_1/index.html'}
# 2025-11-25 16:01:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/short-stories_45/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/novels_46/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/health_47/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/christian_43/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/crime_51/index.html>
#
# {'title': 'The Long Shadow of Small Ghosts: Murder and Memory in an American City', 'price': '£10.97', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-long-shadow-of-small-ghosts-murder-and-memory-in-an-american-city_848/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/cultural_49/index.html>
#
# {'title': 'Amid the Chaos', 'price': '£36.58', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/amid-the-chaos_788/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/erotica_50/index.html>
#
# {'title': 'Dark Notes', 'price': '£19.19', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/politics_48/index.html>
#
# {'title': 'Libertarianism for Beginners', 'price': '£51.33', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/libertarianism-for-beginners_982/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/politics_48/index.html>
#
# {'title': 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond', 'price': '£52.65', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/why-the-right-went-wrong-conservatism-from-goldwater-to-the-tea-party-and-beyond_781/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/politics_48/index.html>
#
# {'title': "Equal Is Unfair: America's Misguided Fight Against Income Inequality", 'price': '£56.86', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/equal-is-unfair-americas-misguided-fight-against-income-inequality_617/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/short-stories_45/index.html>
#
# {'title': 'The Grownup', 'price': '£35.88', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-grownup_546/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/novels_46/index.html>
#
# {'title': 'Suzie Snowflake: One beautiful flake (a self-esteem story)', 'price': '£54.81', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/suzie-snowflake-one-beautiful-flake-a-self-esteem-story_568/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/health_47/index.html>
#
# {'title': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life', 'price': '£49.05', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-bulletproof-diet-lose-up-to-a-pound-a-day-reclaim-energy-and-focus-upgrade-your-life_931/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/health_47/index.html>
#
# {'title': 'Eat Fat, Get Thin', 'price': '£54.07', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/eat-fat-get-thin_688/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/health_47/index.html>
#
# {'title': '10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!', 'price': '£49.71', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/10-day-green-smoothie-cleanse-lose-up-to-15-pounds-in-10-days_581/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/health_47/index.html>
#
# {'title': 'The Art and Science of Low Carbohydrate Living', 'price': '£52.98', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-art-and-science-of-low-carbohydrate-living_570/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian_43/index.html>
#
# {'title': '(Un)Qualified: How God Uses Broken People to Do Big Things', 'price': '£54.00', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/unqualified-how-god-uses-broken-people-to-do-big-things_873/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian_43/index.html>
#
# {'title': 'Crazy Love: Overwhelmed by a Relentless God', 'price': '£47.72', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/crazy-love-overwhelmed-by-a-relentless-god_682/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian_43/index.html>
#
# {'title': 'Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality', 'price': '£25.77', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/blue-like-jazz-nonreligious-thoughts-on-christian-spirituality_461/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/suspense_44/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/contemporary_38/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/thriller_37/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/biography_36/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/suspense_44/index.html>
#
# {'title': 'Silence in the Dark (Logan Point #4)', 'price': '£58.33', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/silence-in-the-dark-logan-point-4_542/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html>
#
# {'title': 'The Four Agreements: A Practical Guide to Personal Freedom', 'price': '£17.66', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-four-agreements-a-practical-guide-to-personal-freedom_970/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html>
#
# {'title': "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution", 'price': '£32.24', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-activists-tao-te-ching-ancient-advice-for-a-modern-revolution_928/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html>
#
# {'title': 'Chasing Heaven: What Dying Taught Me About Living', 'price': '£37.80', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/chasing-heaven-what-dying-taught-me-about-living_797/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html>
#
# {'title': "If I Gave You God's Phone Number....: Searching for Spirituality in America", 'price': '£20.91', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/if-i-gave-you-gods-phone-number-searching-for-spirituality-in-america_564/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html>
#
# {'title': 'Unreasonable Hope: Finding Faith in the God Who Brings Purpose to Your Pain', 'price': '£46.33', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/unreasonable-hope-finding-faith-in-the-god-who-brings-purpose-to-your-pain_505/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html>
#
# {'title': "A New Earth: Awakening to Your Life's Purpose", 'price': '£55.65', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/a-new-earth-awakening-to-your-lifes-purpose_311/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/contemporary_38/index.html>
#
# {'title': 'When We Collided', 'price': '£31.77', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/when-we-collided_955/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/contemporary_38/index.html>
#
# {'title': 'Someone Like You (The Harrisons #2)', 'price': '£52.79', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/someone-like-you-the-harrisons-2_735/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/contemporary_38/index.html>
#
# {'title': 'We Are All Completely Beside Ourselves', 'price': '£24.04', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/we-are-all-completely-beside-ourselves_301/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'title': 'In Her Wake', 'price': '£12.84', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'title': 'The Elephant Tree', 'price': '£23.82', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-elephant-tree_968/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'title': 'Behind Closed Doors', 'price': '£52.22', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/behind-closed-doors_962/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'title': 'You (You #1)', 'price': '£43.61', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/you-you-1_784/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'title': 'The Guilty (Will Robie #4)', 'price': '£13.82', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-guilty-will-robie-4_750/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'title': 'The 14th Colony (Cotton Malone #11)', 'price': '£39.24', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-14th-colony-cotton-malone-11_744/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'title': 'Give It Back', 'price': '£18.32', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/give-it-back_430/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'title': 'Killing Floor (Jack Reacher #1)', 'price': '£31.49', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/killing-floor-jack-reacher-1_382/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'title': 'The Bone Hunters (Lexy Vaughan & Steven Macaulay #2)', 'price': '£59.71', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-bone-hunters-lexy-vaughan-steven-macaulay-2_343/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'title': 'Far From True (Promise Falls Trilogy #2)', 'price': '£34.93', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/far-from-true-promise-falls-trilogy-2_320/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'title': 'The Travelers', 'price': '£15.77', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-travelers_285/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/biography_36/index.html>
#
# {'title': 'Louisa: The Extraordinary Life of Mrs. Adams', 'price': '£16.85', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/louisa-the-extraordinary-life-of-mrs-adams_818/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/biography_36/index.html>
#
# {'title': 'Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena', 'price': '£21.15', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/setting-the-world-on-fire-the-brief-astonishing-life-of-st-catherine-of-siena_603/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/biography_36/index.html>
#
# {'title': "The Faith of Christopher Hitchens: The Restless Soul of the World's Most Notorious Atheist", 'price': '£39.55', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-faith-of-christopher-hitchens-the-restless-soul-of-the-worlds-most-notorious-atheist_495/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/biography_36/index.html>
#
# {'title': 'Benjamin Franklin: An American Life', 'price': '£48.19', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/benjamin-franklin-an-american-life_460/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/biography_36/index.html>
#
# {'title': 'The Rise of Theodore Roosevelt (Theodore Roosevelt #1)', 'price': '£42.57', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-rise-of-theodore-roosevelt-theodore-roosevelt-1_276/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/history_32/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html>
#
# {'title': 'Redeeming Love', 'price': '£20.47', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/redeeming-love_826/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html>
#
# {'title': 'Close to You', 'price': '£49.46', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/close-to-you_798/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html>
#
# {'title': 'Shadows of the Past (Logan Point #1)', 'price': '£39.67', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/shadows-of-the-past-logan-point-1_541/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html>
#
# {'title': 'Like Never Before (Walker Family #2)', 'price': '£28.77', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/like-never-before-walker-family-2_476/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html>
#
# {'title': 'Counted With the Stars (Out from Egypt #1)', 'price': '£17.97', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/counted-with-the-stars-out-from-egypt-1_463/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html>
#
# {'title': 'If I Run (If I Run #1)', 'price': '£49.97', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/if-i-run-if-i-run-1_174/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/horror_31/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/business_35/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/humor_30/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More', 'price': '£30.52', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/foolproof-preserving-a-guide-to-small-batch-jams-jellies-pickles-condiments-and-more-a-foolproof-guide-to-making-small-batch-jams-jellies-pickles-condiments-and-more_978/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!', 'price': '£56.41', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-pioneer-woman-cooks-dinnertime-comfort-classics-freezer-food-16-minute-meals-and-other-delicious-ways-to-solve-supper_943/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'My Paris Kitchen: Recipes and Stories', 'price': '£33.37', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/my-paris-kitchen-recipes-and-stories_910/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed', 'price': '£14.02', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/mama-tried-traditional-italian-cooking-for-the-screwed-crude-vegan-and-tattooed_908/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'Layered: Baking, Building, and Styling Spectacular Cakes', 'price': '£40.11', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/layered-baking-building-and-styling-spectacular-cakes_904/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us', 'price': '£37.34', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-nerdy-nummies-cookbook-sweet-treats-for-the-geek-in-all-of-us_853/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking', 'price': '£37.60', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-love-and-lemons-cookbook-an-apple-to-zucchini-celebration-of-impromptu-cooking_849/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First', 'price': '£41.25', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-cookies-cups-cookbook-125-sweet-savory-recipes-reminding-you-to-always-eat-dessert-first_841/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/adult-fiction_29/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals', 'price': '£42.16', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/deliciously-ella-every-day-quick-and-easy-recipes-for-gluten-free-snacks-packed-lunches-and-simple-meals_801/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth', 'price': '£28.77', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-help-yourself-cookbook-for-kids-60-easy-plant-based-recipes-kids-can-make-to-stay-healthy-and-save-the-earth_751/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': "It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes", 'price': '£19.55', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/its-all-easy-healthy-delicious-weeknight-meals-in-under-30-minutes_706/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'Barefoot Contessa Back to Basics', 'price': '£28.01', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/barefoot-contessa-back-to-basics_667/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again", 'price': '£50.62', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/barefoot-contessa-at-home-everyday-recipes-youll-make-over-and-over-again_666/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'My Kitchen Year: 136 Recipes That Saved My Life', 'price': '£11.53', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/my-kitchen-year-136-recipes-that-saved-my-life_646/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'Everyday Italian: 125 Simple and Delicious Recipes', 'price': '£20.10', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/everyday-italian-125-simple-and-delicious-recipes_618/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More', 'price': '£38.77', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/a-la-mode-120-recipes-in-60-pairings-pies-tarts-cakes-crisps-and-more-topped-with-ice-cream-gelato-frozen-custard-and-more_611/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'Cravings: Recipes for What You Want to Eat', 'price': '£20.50', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/cravings-recipes-for-what-you-want-to-eat_589/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York', 'price': '£12.34', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-moosewood-cookbook-recipes-from-moosewood-restaurant-ithaca-new-york_574/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': '32 Yolks', 'price': '£53.63', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/32-yolks_510/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'title': 'Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories', 'price': '£11.38', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/naturally-lean-125-nourishing-gluten-free-plant-based-recipes-all-under-300-calories_479/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': 'Sapiens: A Brief History of Humankind', 'price': '£54.23', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': 'Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink', 'price': '£25.52', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/unbound-how-eight-technologies-made-us-human-transformed-society-and-brought-our-world-to-the-brink_950/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': 'The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind', 'price': '£19.73', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-age-of-genius-the-seventeenth-century-and-the-birth-of-the-modern-mind_929/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics', 'price': '£36.28', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/political-suicide-missteps-peccadilloes-bad-calls-backroom-hijinx-sordid-pasts-rotten-breaks-and-just-plain-dumb-mistakes-in-the-annals-of-american-politics_917/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History', 'price': '£59.64', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/thomas-jefferson-and-the-tripoli-pirates-the-forgotten-war-that-changed-american-history_867/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': 'Zealot: The Life and Times of Jesus of Nazareth', 'price': '£24.70', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/zealot-the-life-and-times-of-jesus-of-nazareth_785/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': 'A Distant Mirror: The Calamitous 14th Century', 'price': '£14.58', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/a-distant-mirror-the-calamitous-14th-century_652/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': '1491: New Revelations of the Americas Before Columbus', 'price': '£21.80', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/1491-new-revelations-of-the-americas-before-columbus_650/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': 'Brilliant Beacons: A History of the American Lighthouse', 'price': '£11.45', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/brilliant-beacons-a-history-of-the-american-lighthouse_515/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': '"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination', 'price': '£44.48', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/most-blessed-of-the-patriarchs-thomas-jefferson-and-the-empire-of-the-imagination_509/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': 'A Short History of Nearly Everything', 'price': '£52.40', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/a-short-history-of-nearly-everything_457/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': 'The Rise and Fall of the Third Reich: A History of Nazi Germany', 'price': '£39.67', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-rise-and-fall-of-the-third-reich-a-history-of-nazi-germany_454/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': 'Catherine the Great: Portrait of a Woman', 'price': '£58.55', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/catherine-the-great-portrait-of-a-woman_424/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': "The Mathews Men: Seven Brothers and the War Against Hitler's U-boats", 'price': '£42.91', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-mathews-men-seven-brothers-and-the-war-against-hitlers-u-boats_408/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': 'The Hiding Place', 'price': '£55.91', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-hiding-place_406/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': "America's War for the Greater Middle East: A Military History", 'price': '£51.22', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/americas-war-for-the-greater-middle-east-a-military-history_361/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': 'The Guns of August', 'price': '£14.54', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-guns-of-august_254/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'title': 'House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth', 'price': '£43.70', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/house-of-lost-worlds-dinosaurs-dynasties-and-the-story-of-life-on-earth_170/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/parenting_28/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/horror_31/index.html>
#
# {'title': 'Security', 'price': '£39.25', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/security_925/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/horror_31/index.html>
#
# {'title': 'Follow You Home', 'price': '£21.36', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/follow-you-home_809/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/horror_31/index.html>
#
# {'title': 'The Loney', 'price': '£23.40', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-loney_756/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/horror_31/index.html>
#
# {'title': 'Pet Sematary', 'price': '£10.56', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/pet-sematary_726/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/horror_31/index.html>
#
# {'title': 'Doctor Sleep (The Shining #2)', 'price': '£40.12', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/doctor-sleep-the-shining-2_686/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/horror_31/index.html>
#
# {'title': 'Psycho: Sanitarium (Psycho #1.5)', 'price': '£36.97', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/psycho-sanitarium-psycho-15_628/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/horror_31/index.html>
#
# {'title': 'Can You Keep a Secret? (Fear Street Relaunch #4)', 'price': '£48.64', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/can-you-keep-a-secret-fear-street-relaunch-4_614/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/horror_31/index.html>
#
# {'title': 'Red Dragon (Hannibal Lecter #1)', 'price': '£23.37', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/red-dragon-hannibal-lecter-1_390/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/horror_31/index.html>
#
# {'title': 'Dracula the Un-Dead', 'price': '£35.63', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/dracula-the-un-dead_370/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/horror_31/index.html>
#
# {'title': 'Night Shift (Night Shift #1-20)', 'price': '£12.75', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/night-shift-night-shift-1-20_335/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/autobiography_27/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/horror_31/index.html>
#
# {'title': 'Needful Things', 'price': '£47.51', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/needful-things_334/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/horror_31/index.html>
#
# {'title': 'Misery', 'price': '£34.79', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/misery_332/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/horror_31/index.html>
#
# {'title': 'It', 'price': '£25.01', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/it_330/index.html'}
# 2025-11-25 16:01:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/horror_31/index.html>
#
# {'title': "'Salem's Lot", 'price': '£49.56', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/salems-lot_309/index.html'}
# ...
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'title': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)', 'price': '£19.92', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/lumberjanes-vol-3-a-terrible-plan-lumberjanes-9-12_905/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'title': 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)', 'price': '£29.17', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/i-hate-fairyland-vol-1-madly-ever-after-i-hate-fairyland-compilations-1-5_899/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'title': 'I am a Hero Omnibus Volume 1', 'price': '£54.63', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/i-am-a-hero-omnibus-volume-1_898/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'title': 'Giant Days, Vol. 2 (Giant Days #5-8)', 'price': '£22.11', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/giant-days-vol-2-giant-days-5-8_895/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'title': 'Danganronpa Volume 1', 'price': '£51.99', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/danganronpa-volume-1_889/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'title': 'Codename Baboushka, Volume 1: The Conclave of Death', 'price': '£36.72', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/codename-baboushka-volume-1-the-conclave-of-death_887/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'title': 'Camp Midnight', 'price': '£17.08', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/camp-midnight_886/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'Sharp Objects', 'price': '£47.82', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/sharp-objects_997/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'In a Dark, Dark Wood', 'price': '£19.63', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/in-a-dark-dark-wood_963/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'The Past Never Ends', 'price': '£56.50', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-past-never-ends_942/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'A Murder in Time', 'price': '£16.64', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/a-murder-in-time_877/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'The Murder of Roger Ackroyd (Hercule Poirot #4)', 'price': '£44.10', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-murder-of-roger-ackroyd-hercule-poirot-4_852/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'The Last Mile (Amos Decker #2)', 'price': '£54.21', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-last-mile-amos-decker-2_754/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'That Darkness (Gardiner and Renner #1)', 'price': '£13.92', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/that-darkness-gardiner-and-renner-1_743/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'Tastes Like Fear (DI Marnie Rome #3)', 'price': '£10.69', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/tastes-like-fear-di-marnie-rome-3_742/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'A Time of Torment (Charlie Parker #14)', 'price': '£48.35', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/a-time-of-torment-charlie-parker-14_657/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'A Study in Scarlet (Sherlock Holmes #1)', 'price': '£16.73', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/a-study-in-scarlet-sherlock-holmes-1_656/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'Poisonous (Max Revere Novels #3)', 'price': '£26.80', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/poisonous-max-revere-novels-3_627/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'Murder at the 42nd Street Library (Raymond Ambler #1)', 'price': '£54.36', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/murder-at-the-42nd-street-library-raymond-ambler-1_624/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'Most Wanted', 'price': '£35.28', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/most-wanted_623/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'Hide Away (Eve Duncan #20)', 'price': '£11.84', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'Boar Island (Anna Pigeon #19)', 'price': '£59.48', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/boar-island-anna-pigeon-19_613/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'The Widow', 'price': '£27.26', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-widow_609/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'Playing with Fire', 'price': '£13.71', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/playing-with-fire_602/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'What Happened on Beale Street (Secrets of the South Mysteries #2)', 'price': '£25.37', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/what-happened-on-beale-street-secrets-of-the-south-mysteries-2_506/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': "The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)", 'price': '£52.30', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-bachelor-girls-guide-to-murder-herringford-and-watts-mysteries-1_491/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'title': 'Delivering the Truth (Quaker Midwife Mystery #1)', 'price': '£20.89', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/delivering-the-truth-quaker-midwife-mystery-1_464/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': 'I Had a Nice Time And Other Lies...: How to find love & sh*t like that', 'price': '£57.36', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/i-had-a-nice-time-and-other-lies-how-to-find-love-sht-like-that_814/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': "Will You Won't You Want Me?", 'price': '£13.86', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/will-you-wont-you-want-me_644/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': 'Keep Me Posted', 'price': '£20.46', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/keep-me-posted_594/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': 'Grey (Fifty Shades #4)', 'price': '£48.49', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/grey-fifty-shades-4_592/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': 'Meternity', 'price': '£43.58', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/meternity_478/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': 'Some Women', 'price': '£13.73', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/some-women_341/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': 'Shopaholic Ties the Knot (Shopaholic #3)', 'price': '£48.39', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/shopaholic-ties-the-knot-shopaholic-3_340/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': 'Can You Keep a Secret?', 'price': '£21.94', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/can-you-keep-a-secret_315/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': 'Twenties Girl', 'price': '£42.80', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/twenties-girl_292/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': 'The Undomestic Goddess', 'price': '£45.75', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-undomestic-goddess_286/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': 'The Nanny Diaries (Nanny #1)', 'price': '£52.53', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-nanny-diaries-nanny-1_265/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': 'The Devil Wears Prada (The Devil Wears Prada #1)', 'price': '£44.29', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-devil-wears-prada-the-devil-wears-prada-1_243/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': 'Something Borrowed (Darcy & Rachel #1)', 'price': '£48.96', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/something-borrowed-darcy-rachel-1_224/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': 'Something Blue (Darcy & Rachel #2)', 'price': '£54.62', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/something-blue-darcy-rachel-2_223/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': "I've Got Your Number", 'price': '£19.69', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/ive-got-your-number_173/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': 'The Edge of Reason (Bridget Jones #2)', 'price': '£19.18', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/the-edge-of-reason-bridget-jones-2_63/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
#
# {'title': "Bridget Jones's Diary (Bridget Jones #1)", 'price': '£29.82', 'availability': 'In stock', 'url': 'https://books.toscrape.com/catalogue/bridget-joness-diary-bridget-jones-1_10/index.html'}
# 2025-11-25 16:01:22 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-11-25 16:01:22 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 15657,
#  'downloader/request_count': 52,
#  'downloader/request_method_count/GET': 52,
#  'downloader/response_bytes': 1858524,
#  'downloader/response_count': 52,
#  'downloader/response_status_count/200': 51,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 3.044346,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 11, 25, 15, 1, 22, 435749, tzinfo=datetime.timezone.utc),
#  'item_scraped_count': 517,
#  'log_count/DEBUG': 570,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'request_depth_max': 1,
#  'response_received_count': 52,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 51,
#  'scheduler/dequeued/memory': 51,
#  'scheduler/enqueued': 51,
#  'scheduler/enqueued/memory': 51,
#  'start_time': datetime.datetime(2025, 11, 25, 15, 1, 19, 391403, tzinfo=datetime.timezone.utc)}
# 2025-11-25 16:01:22 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On peut exporter les résultats de ces retours dans différents formats de
# fichiers.
#
# -   CSV : `scrapy crawl lemondev3 -o lemonde.csv`
# -   JSON : `scrapy crawl lemondev3 -o lemonde.json`
# -   JSONLINE : `scrapy crawl lemondev3 -o lemonde.jl`
# -   XML : `scrapy crawl lemondev3 -o lemonde.xml`
#
# ### Exercice :
#
# Exécuter la spider avec les différents formats de stockage.
# Explorer ensuite le contenu des fichiers ainsi créés.

# %% [markdown]
# ## Votre premier Item
#
# La classe `Item` permet de structurer les données que l'on souhaite
# récupérer sous la forme d'un modèle. Les items doivent être définis dans
# le fichier `items.py` créé par la commande `scrapy startproject`. Les
# `Item` héritent de la class `scrapy.Item`.
#
# On veut structurer les données avec trois champs : le titre, l'image et la description. Scrapy utilise une classe `scrapy.Field` permettant de 'déclarer' ces champs. Dans notre cas :

# %%
# %load newscrawler/newscrawler/items.py

# Define here the models for your scraped items
#
# See documentation in:
# https://docs.scrapy.org/en/latest/topics/items.html

import scrapy


class ArticleItem(scrapy.Item):
    title = scrapy.Field()
    image = scrapy.Field()
    description = scrapy.Field()

# %% [markdown]
# Utiliser la classe `scrapy.Item` plutôt qu'un simple dictionnaire permet
# plus de contrôle sur la structure des données. En effet, on ne peut
# insérer dans les items que des données avec des clés 'déclarées'. Ce qui
# assure une plus grande cohérence au sein d'un projet.
#
# On peut instancier un item de plusieurs façons :

# %%
article_item = ArticleItem(title="Yann Lecun and Meta sortent Llama 3.2", image=None, description="LLama 3.2 n'est pas disponible en france")

# %%
print(article_item)
# Out:
# {'description': "LLama 3.2 n'est pas disponible en france",
#  'image': None,
#  'title': 'Yann Lecun and Meta sortent Llama 3.2'}

# %%
article_item = ArticleItem()
article_item["title"] = 'Léon Marchand recoit la légion d\'honneur'
article_item["description"] = 'Quadruple champion olympic'

# %%
print(article_item)
# Out:
# {'description': 'Quadruple champion olympic',
#  'title': "Léon Marchand recoit la légion d'honneur"}

# %% [markdown]
# La définition d'un item permet de palier toutes les erreurs de typo dans
# les champs.

# %%
article_item = ArticleItem()
article_item["titelkjwnxvmnscbvmknxc"] = 'Erreur exemple'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 article_item = ArticleItem()
# ----> 2 article_item["titelkjwnxvmnscbvmknxc"] = 'Erreur exemple'
#
# File c:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\item.py:85, in Item.__setitem__(self, key, value)
#      83     self._values[key] = value
#      84 else:
# ---> 85     raise KeyError(f"{self.__class__.__name__} does not support field: {key}")
#
# KeyError: 'ArticleItem does not support field: titelkjwnxvmnscbvmknxc'

# %% [markdown]
# Les items héritent des dictionnaires Python, et possèdent donc toutes
# les méthodes de ceux-ci :

# %%
article_item = ArticleItem(title="Nouvelle lamborghini")
print(article_item["title"])  # Méthode __getitem__()
print(article_item.get("description", "no description provided"))  # Méthode get()
# Out:
# Nouvelle lamborghini
# no description provided

# %% [markdown]
# On peut transformer un `Item` en dictionnaire très facilement, en le
# passant au constructeur:

# %%
article_item = ArticleItem(title="Drone DJI")
print(type(article_item))
dict_item = dict(article_item)
print(type(dict_item))
print(dict_item)
# Out:
# <class '__main__.ArticleItem'>
# <class 'dict'>
# {'title': 'Drone DJI'}

# %% [markdown]
# On intègre maintenant cet item dans notre spider.

# %%
# %load newscrawler/newscrawler/spiders/booksv4.py
import scrapy
from scrapy import Request


# Définir BookItem pour l'exemple
class BookItem(scrapy.Item):
    title = scrapy.Field()
    price = scrapy.Field()
    availability = scrapy.Field()
    url = scrapy.Field()


class BooksSpider(scrapy.Spider):
    name = "booksv4"
    allowed_domains = ["books.toscrape.com"]
    start_urls = ['https://books.toscrape.com']

    def parse(self, response, **kwargs):
        # Récupérer toutes les catégories de livres
        categories = {}
        for category in response.css('ul.nav-list ul li a'):
            name = category.css('::text').extract_first().strip()
            url = response.urljoin(category.css('::attr(href)').extract_first())
            categories[name] = url
        
        # Suivre les liens des catégories
        for link in categories.values():
            yield Request(link, callback=self.parse_category)
    
    def parse_category(self, response):
        # Extraire les livres de chaque catégorie
        for book in response.css('article.product_pod'):
            title = book.css('h3 a::attr(title)').extract_first()
            price = book.css('.price_color::text').extract_first()
            availability = book.css('.availability::text').extract()[1].strip()
            url = response.urljoin(book.css('h3 a::attr(href)').extract_first())
            
            yield BookItem(
                title=title,
                price=price,
                availability=availability,
                url=url
            )

    def clean_spaces(self, string):
        if string:
            return " ".join(string.split())

# %% [markdown]
# On voit bien que le générateur retourne maintenant un `Item`.

# %% [markdown]
# ### Exercice :
#
# Relancer la spider pour vérifier le bon déroulement de l'extraction.

# %%
# !cd newscrawler && scrapy crawl booksv4
# Out:
# 2025-11-25 16:16:52 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: newscrawler)
# 2025-11-25 16:16:52 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.11.7, cssselect 1.3.0, parsel 1.10.0, w3lib 2.3.1, Twisted 25.5.0, Python 3.12.12 (main, Oct 31 2025, 23:00:21) [MSC v.1944 64 bit (AMD64)], pyOpenSSL 25.3.0 (OpenSSL 3.5.4 30 Sep 2025), cryptography 46.0.3, Platform Windows-11-10.0.26200-SP0
# 2025-11-25 16:16:52 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-11-25 16:16:52 [py.warnings] WARNING: C:\Users\lucca\Documents\ESIEE E4 DSIA S1\DataEngineerTools\.venv\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2025-11-25 16:16:52 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2025-11-25 16:16:52 [scrapy.extensions.telnet] INFO: Telnet Password: 5991ce2c36bac75c
# 2025-11-25 16:16:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2025-11-25 16:16:52 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2025-11-25 16:16:53 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-11-25 16:16:53 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-11-25 16:16:53 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-11-25 16:16:53 [scrapy.core.engine] INFO: Spider opened
# 2025-11-25 16:16:53 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-11-25 16:16:53 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-11-25 16:16:53 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://books.toscrape.com/robots.txt> (referer: None)
# 2025-11-25 16:16:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com> (referer: None)
# 2025-11-25 16:16:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/travel_2/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'availability': 'In stock',
#  'price': '£45.17',
#  'title': "It's Only the Himalayas",
#  'url': 'https://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'availability': 'In stock',
#  'price': '£49.43',
#  'title': 'Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond',
#  'url': 'https://books.toscrape.com/catalogue/full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'availability': 'In stock',
#  'price': '£48.87',
#  'title': 'See America: A Celebration of Our National Parks & Treasured Sites',
#  'url': 'https://books.toscrape.com/catalogue/see-america-a-celebration-of-our-national-parks-treasured-sites_732/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'availability': 'In stock',
#  'price': '£36.94',
#  'title': 'Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel',
#  'url': 'https://books.toscrape.com/catalogue/vagabonding-an-uncommon-guide-to-the-art-of-long-term-world-travel_552/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'availability': 'In stock',
#  'price': '£37.33',
#  'title': 'Under the Tuscan Sun',
#  'url': 'https://books.toscrape.com/catalogue/under-the-tuscan-sun_504/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'availability': 'In stock',
#  'price': '£44.34',
#  'title': 'A Summer In Europe',
#  'url': 'https://books.toscrape.com/catalogue/a-summer-in-europe_458/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'availability': 'In stock',
#  'price': '£30.54',
#  'title': 'The Great Railway Bazaar',
#  'url': 'https://books.toscrape.com/catalogue/the-great-railway-bazaar_446/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'availability': 'In stock',
#  'price': '£56.88',
#  'title': 'A Year in Provence (Provence #1)',
#  'url': 'https://books.toscrape.com/catalogue/a-year-in-provence-provence-1_421/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'availability': 'In stock',
#  'price': '£23.21',
#  'title': 'The Road to Little Dribbling: Adventures of an American in Britain '
#           '(Notes From a Small Island #2)',
#  'url': 'https://books.toscrape.com/catalogue/the-road-to-little-dribbling-adventures-of-an-american-in-britain-notes-from-a-small-island-2_277/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'availability': 'In stock',
#  'price': '£38.95',
#  'title': 'Neither Here nor There: Travels in Europe',
#  'url': 'https://books.toscrape.com/catalogue/neither-here-nor-there-travels-in-europe_198/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/travel_2/index.html>
#
# {'availability': 'In stock',
#  'price': '£26.08',
#  'title': '1,000 Places to See Before You Die',
#  'url': 'https://books.toscrape.com/catalogue/1000-places-to-see-before-you-die_1/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html>
#
# {'availability': 'In stock',
#  'price': '£17.66',
#  'title': 'The Four Agreements: A Practical Guide to Personal Freedom',
#  'url': 'https://books.toscrape.com/catalogue/the-four-agreements-a-practical-guide-to-personal-freedom_970/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html>
#
# {'availability': 'In stock',
#  'price': '£32.24',
#  'title': "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution",
#  'url': 'https://books.toscrape.com/catalogue/the-activists-tao-te-ching-ancient-advice-for-a-modern-revolution_928/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html>
#
# {'availability': 'In stock',
#  'price': '£37.80',
#  'title': 'Chasing Heaven: What Dying Taught Me About Living',
#  'url': 'https://books.toscrape.com/catalogue/chasing-heaven-what-dying-taught-me-about-living_797/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html>
#
# {'availability': 'In stock',
#  'price': '£20.91',
#  'title': "If I Gave You God's Phone Number....: Searching for Spirituality in "
#           'America',
#  'url': 'https://books.toscrape.com/catalogue/if-i-gave-you-gods-phone-number-searching-for-spirituality-in-america_564/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html>
#
# {'availability': 'In stock',
#  'price': '£46.33',
#  'title': 'Unreasonable Hope: Finding Faith in the God Who Brings Purpose to '
#           'Your Pain',
#  'url': 'https://books.toscrape.com/catalogue/unreasonable-hope-finding-faith-in-the-god-who-brings-purpose-to-your-pain_505/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/spirituality_39/index.html>
#
# {'availability': 'In stock',
#  'price': '£55.65',
#  'title': "A New Earth: Awakening to Your Life's Purpose",
#  'url': 'https://books.toscrape.com/catalogue/a-new-earth-awakening-to-your-lifes-purpose_311/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/contemporary_38/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/novels_46/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/contemporary_38/index.html>
#
# {'availability': 'In stock',
#  'price': '£31.77',
#  'title': 'When We Collided',
#  'url': 'https://books.toscrape.com/catalogue/when-we-collided_955/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/contemporary_38/index.html>
#
# {'availability': 'In stock',
#  'price': '£52.79',
#  'title': 'Someone Like You (The Harrisons #2)',
#  'url': 'https://books.toscrape.com/catalogue/someone-like-you-the-harrisons-2_735/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/contemporary_38/index.html>
#
# {'availability': 'In stock',
#  'price': '£24.04',
#  'title': 'We Are All Completely Beside Ourselves',
#  'url': 'https://books.toscrape.com/catalogue/we-are-all-completely-beside-ourselves_301/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/suspense_44/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/christian_43/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/academic_40/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/historical_42/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/self-help_41/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/short-stories_45/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/novels_46/index.html>
#
# {'availability': 'In stock',
#  'price': '£54.81',
#  'title': 'Suzie Snowflake: One beautiful flake (a self-esteem story)',
#  'url': 'https://books.toscrape.com/catalogue/suzie-snowflake-one-beautiful-flake-a-self-esteem-story_568/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/thriller_37/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/suspense_44/index.html>
#
# {'availability': 'In stock',
#  'price': '£58.33',
#  'title': 'Silence in the Dark (Logan Point #4)',
#  'url': 'https://books.toscrape.com/catalogue/silence-in-the-dark-logan-point-4_542/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian_43/index.html>
#
# {'availability': 'In stock',
#  'price': '£54.00',
#  'title': '(Un)Qualified: How God Uses Broken People to Do Big Things',
#  'url': 'https://books.toscrape.com/catalogue/unqualified-how-god-uses-broken-people-to-do-big-things_873/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian_43/index.html>
#
# {'availability': 'In stock',
#  'price': '£47.72',
#  'title': 'Crazy Love: Overwhelmed by a Relentless God',
#  'url': 'https://books.toscrape.com/catalogue/crazy-love-overwhelmed-by-a-relentless-god_682/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian_43/index.html>
#
# {'availability': 'In stock',
#  'price': '£25.77',
#  'title': 'Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality',
#  'url': 'https://books.toscrape.com/catalogue/blue-like-jazz-nonreligious-thoughts-on-christian-spirituality_461/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/biography_36/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/academic_40/index.html>
#
# {'availability': 'In stock',
#  'price': '£13.12',
#  'title': 'Logan Kade (Fallen Crest High #5.5)',
#  'url': 'https://books.toscrape.com/catalogue/logan-kade-fallen-crest-high-55_384/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/historical_42/index.html>
#
# {'availability': 'In stock',
#  'price': '£29.87',
#  'title': 'All the Light We Cannot See',
#  'url': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/historical_42/index.html>
#
# {'availability': 'In stock',
#  'price': '£15.79',
#  'title': 'The Girl You Left Behind (The Girl You Left Behind #1)',
#  'url': 'https://books.toscrape.com/catalogue/the-girl-you-left-behind-the-girl-you-left-behind-1_443/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/self-help_41/index.html>
#
# {'availability': 'In stock',
#  'price': '£46.35',
#  'title': 'Online Marketing for Busy Authors: A Step-By-Step Guide',
#  'url': 'https://books.toscrape.com/catalogue/online-marketing-for-busy-authors-a-step-by-step-guide_913/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/self-help_41/index.html>
#
# {'availability': 'In stock',
#  'price': '£46.03',
#  'title': 'How to Be Miserable: 40 Strategies You Already Use',
#  'url': 'https://books.toscrape.com/catalogue/how-to-be-miserable-40-strategies-you-already-use_897/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/self-help_41/index.html>
#
# {'availability': 'In stock',
#  'price': '£52.15',
#  'title': 'Overload: How to Unplug, Unwind, and Unleash Yourself from the '
#           'Pressure of Stress',
#  'url': 'https://books.toscrape.com/catalogue/overload-how-to-unplug-unwind-and-unleash-yourself-from-the-pressure-of-stress_725/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/self-help_41/index.html>
#
# {'availability': 'In stock',
#  'price': '£12.08',
#  'title': 'You Are a Badass: How to Stop Doubting Your Greatness and Start '
#           'Living an Awesome Life',
#  'url': 'https://books.toscrape.com/catalogue/you-are-a-badass-how-to-stop-doubting-your-greatness-and-start-living-an-awesome-life_508/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/self-help_41/index.html>
#
# {'availability': 'In stock',
#  'price': '£46.49',
#  'title': 'How to Stop Worrying and Start Living',
#  'url': 'https://books.toscrape.com/catalogue/how-to-stop-worrying-and-start-living_431/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/short-stories_45/index.html>
#
# {'availability': 'In stock',
#  'price': '£35.88',
#  'title': 'The Grownup',
#  'url': 'https://books.toscrape.com/catalogue/the-grownup_546/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/erotica_50/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/crime_51/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'availability': 'In stock',
#  'price': '£12.84',
#  'title': 'In Her Wake',
#  'url': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'availability': 'In stock',
#  'price': '£23.82',
#  'title': 'The Elephant Tree',
#  'url': 'https://books.toscrape.com/catalogue/the-elephant-tree_968/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'availability': 'In stock',
#  'price': '£52.22',
#  'title': 'Behind Closed Doors',
#  'url': 'https://books.toscrape.com/catalogue/behind-closed-doors_962/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'availability': 'In stock',
#  'price': '£43.61',
#  'title': 'You (You #1)',
#  'url': 'https://books.toscrape.com/catalogue/you-you-1_784/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'availability': 'In stock',
#  'price': '£13.82',
#  'title': 'The Guilty (Will Robie #4)',
#  'url': 'https://books.toscrape.com/catalogue/the-guilty-will-robie-4_750/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'availability': 'In stock',
#  'price': '£39.24',
#  'title': 'The 14th Colony (Cotton Malone #11)',
#  'url': 'https://books.toscrape.com/catalogue/the-14th-colony-cotton-malone-11_744/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'availability': 'In stock',
#  'price': '£18.32',
#  'title': 'Give It Back',
#  'url': 'https://books.toscrape.com/catalogue/give-it-back_430/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'availability': 'In stock',
#  'price': '£31.49',
#  'title': 'Killing Floor (Jack Reacher #1)',
#  'url': 'https://books.toscrape.com/catalogue/killing-floor-jack-reacher-1_382/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'availability': 'In stock',
#  'price': '£59.71',
#  'title': 'The Bone Hunters (Lexy Vaughan & Steven Macaulay #2)',
#  'url': 'https://books.toscrape.com/catalogue/the-bone-hunters-lexy-vaughan-steven-macaulay-2_343/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'availability': 'In stock',
#  'price': '£34.93',
#  'title': 'Far From True (Promise Falls Trilogy #2)',
#  'url': 'https://books.toscrape.com/catalogue/far-from-true-promise-falls-trilogy-2_320/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/thriller_37/index.html>
#
# {'availability': 'In stock',
#  'price': '£15.77',
#  'title': 'The Travelers',
#  'url': 'https://books.toscrape.com/catalogue/the-travelers_285/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/biography_36/index.html>
#
# {'availability': 'In stock',
#  'price': '£16.85',
#  'title': 'Louisa: The Extraordinary Life of Mrs. Adams',
#  'url': 'https://books.toscrape.com/catalogue/louisa-the-extraordinary-life-of-mrs-adams_818/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/biography_36/index.html>
#
# {'availability': 'In stock',
#  'price': '£21.15',
#  'title': 'Setting the World on Fire: The Brief, Astonishing Life of St. '
#           'Catherine of Siena',
#  'url': 'https://books.toscrape.com/catalogue/setting-the-world-on-fire-the-brief-astonishing-life-of-st-catherine-of-siena_603/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/biography_36/index.html>
#
# {'availability': 'In stock',
#  'price': '£39.55',
#  'title': "The Faith of Christopher Hitchens: The Restless Soul of the World's "
#           'Most Notorious Atheist',
#  'url': 'https://books.toscrape.com/catalogue/the-faith-of-christopher-hitchens-the-restless-soul-of-the-worlds-most-notorious-atheist_495/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/biography_36/index.html>
#
# {'availability': 'In stock',
#  'price': '£48.19',
#  'title': 'Benjamin Franklin: An American Life',
#  'url': 'https://books.toscrape.com/catalogue/benjamin-franklin-an-american-life_460/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/biography_36/index.html>
#
# {'availability': 'In stock',
#  'price': '£42.57',
#  'title': 'The Rise of Theodore Roosevelt (Theodore Roosevelt #1)',
#  'url': 'https://books.toscrape.com/catalogue/the-rise-of-theodore-roosevelt-theodore-roosevelt-1_276/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/politics_48/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/cultural_49/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/business_35/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html>
#
# {'availability': 'In stock',
#  'price': '£20.47',
#  'title': 'Redeeming Love',
#  'url': 'https://books.toscrape.com/catalogue/redeeming-love_826/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html>
#
# {'availability': 'In stock',
#  'price': '£49.46',
#  'title': 'Close to You',
#  'url': 'https://books.toscrape.com/catalogue/close-to-you_798/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html>
#
# {'availability': 'In stock',
#  'price': '£39.67',
#  'title': 'Shadows of the Past (Logan Point #1)',
#  'url': 'https://books.toscrape.com/catalogue/shadows-of-the-past-logan-point-1_541/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html>
#
# {'availability': 'In stock',
#  'price': '£28.77',
#  'title': 'Like Never Before (Walker Family #2)',
#  'url': 'https://books.toscrape.com/catalogue/like-never-before-walker-family-2_476/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html>
#
# {'availability': 'In stock',
#  'price': '£17.97',
#  'title': 'Counted With the Stars (Out from Egypt #1)',
#  'url': 'https://books.toscrape.com/catalogue/counted-with-the-stars-out-from-egypt-1_463/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html>
#
# {'availability': 'In stock',
#  'price': '£49.97',
#  'title': 'If I Run (If I Run #1)',
#  'url': 'https://books.toscrape.com/catalogue/if-i-run-if-i-run-1_174/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/history_32/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/health_47/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/erotica_50/index.html>
#
# {'availability': 'In stock',
#  'price': '£19.19',
#  'title': 'Dark Notes',
#  'url': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/crime_51/index.html>
#
# {'availability': 'In stock',
#  'price': '£10.97',
#  'title': 'The Long Shadow of Small Ghosts: Murder and Memory in an American '
#           'City',
#  'url': 'https://books.toscrape.com/catalogue/the-long-shadow-of-small-ghosts-murder-and-memory-in-an-american-city_848/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/horror_31/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/humor_30/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/adult-fiction_29/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/parenting_28/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/politics_48/index.html>
#
# {'availability': 'In stock',
#  'price': '£51.33',
#  'title': 'Libertarianism for Beginners',
#  'url': 'https://books.toscrape.com/catalogue/libertarianism-for-beginners_982/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/politics_48/index.html>
#
# {'availability': 'In stock',
#  'price': '£52.65',
#  'title': 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea '
#           'Party and Beyond',
#  'url': 'https://books.toscrape.com/catalogue/why-the-right-went-wrong-conservatism-from-goldwater-to-the-tea-party-and-beyond_781/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/politics_48/index.html>
#
# {'availability': 'In stock',
#  'price': '£56.86',
#  'title': "Equal Is Unfair: America's Misguided Fight Against Income "
#           'Inequality',
#  'url': 'https://books.toscrape.com/catalogue/equal-is-unfair-americas-misguided-fight-against-income-inequality_617/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/cultural_49/index.html>
#
# {'availability': 'In stock',
#  'price': '£36.58',
#  'title': 'Amid the Chaos',
#  'url': 'https://books.toscrape.com/catalogue/amid-the-chaos_788/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/business_35/index.html>
#
# {'availability': 'In stock',
#  'price': '£33.34',
#  'title': 'The Dirty Little Secrets of Getting Your Dream Job',
#  'url': 'https://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/business_35/index.html>
#
# {'availability': 'In stock',
#  'price': '£12.61',
#  'title': 'The Third Wave: An Entrepreneur’s Vision of the Future',
#  'url': 'https://books.toscrape.com/catalogue/the-third-wave-an-entrepreneurs-vision-of-the-future_862/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/business_35/index.html>
#
# {'availability': 'In stock',
#  'price': '£27.55',
#  'title': 'The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your '
#           'Day Job',
#  'url': 'https://books.toscrape.com/catalogue/the-10-entrepreneur-live-your-startup-dream-without-quitting-your-day-job_836/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/business_35/index.html>
#
# {'availability': 'In stock',
#  'price': '£23.99',
#  'title': 'Shoe Dog: A Memoir by the Creator of NIKE',
#  'url': 'https://books.toscrape.com/catalogue/shoe-dog-a-memoir-by-the-creator-of-nike_831/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/business_35/index.html>
#
# {'availability': 'In stock',
#  'price': '£38.85',
#  'title': 'Made to Stick: Why Some Ideas Survive and Others Die',
#  'url': 'https://books.toscrape.com/catalogue/made-to-stick-why-some-ideas-survive-and-others-die_715/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/business_35/index.html>
#
# {'availability': 'In stock',
#  'price': '£43.14',
#  'title': 'Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two',
#  'url': 'https://books.toscrape.com/catalogue/quench-your-own-thirst-business-lessons-learned-over-a-beer-or-two_629/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/business_35/index.html>
#
# {'availability': 'In stock',
#  'price': '£21.00',
#  'title': 'The Art of Startup Fundraising',
#  'url': 'https://books.toscrape.com/catalogue/the-art-of-startup-fundraising_606/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/business_35/index.html>
#
# {'availability': 'In stock',
#  'price': '£21.59',
#  'title': 'Born for This: How to Find the Work You Were Meant to Do',
#  'url': 'https://books.toscrape.com/catalogue/born-for-this-how-to-find-the-work-you-were-meant-to-do_588/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/business_35/index.html>
#
# {'availability': 'In stock',
#  'price': '£36.91',
#  'title': "The E-Myth Revisited: Why Most Small Businesses Don't Work and What "
#           'to Do About It',
#  'url': 'https://books.toscrape.com/catalogue/the-e-myth-revisited-why-most-small-businesses-dont-work-and-what-to-do-about-it_545/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/business_35/index.html>
#
# {'availability': 'In stock',
#  'price': '£51.74',
#  'title': 'Rich Dad, Poor Dad',
#  'url': 'https://books.toscrape.com/catalogue/rich-dad-poor-dad_483/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/business_35/index.html>
#
# {'availability': 'In stock',
#  'price': '£33.92',
#  'title': "The Lean Startup: How Today's Entrepreneurs Use Continuous "
#           'Innovation to Create Radically Successful Businesses',
#  'url': 'https://books.toscrape.com/catalogue/the-lean-startup-how-todays-entrepreneurs-use-continuous-innovation-to-create-radically-successful-businesses_260/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/autobiography_27/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/art_25/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/psychology_26/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/catalogue/category/books/paranormal_24/index.html> (referer: https://books.toscrape.com)
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'availability': 'In stock',
#  'price': '£30.52',
#  'title': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, '
#           'Pickles, Condiments, and More: A Foolproof Guide to Making Small '
#           'Batch Jams, Jellies, Pickles, Condiments, and More',
#  'url': 'https://books.toscrape.com/catalogue/foolproof-preserving-a-guide-to-small-batch-jams-jellies-pickles-condiments-and-more-a-foolproof-guide-to-making-small-batch-jams-jellies-pickles-condiments-and-more_978/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'availability': 'In stock',
#  'price': '£56.41',
#  'title': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer '
#           'Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!',
#  'url': 'https://books.toscrape.com/catalogue/the-pioneer-woman-cooks-dinnertime-comfort-classics-freezer-food-16-minute-meals-and-other-delicious-ways-to-solve-supper_943/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'availability': 'In stock',
#  'price': '£33.37',
#  'title': 'My Paris Kitchen: Recipes and Stories',
#  'url': 'https://books.toscrape.com/catalogue/my-paris-kitchen-recipes-and-stories_910/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'availability': 'In stock',
#  'price': '£14.02',
#  'title': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, '
#           'Vegan, and Tattooed',
#  'url': 'https://books.toscrape.com/catalogue/mama-tried-traditional-italian-cooking-for-the-screwed-crude-vegan-and-tattooed_908/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'availability': 'In stock',
#  'price': '£40.11',
#  'title': 'Layered: Baking, Building, and Styling Spectacular Cakes',
#  'url': 'https://books.toscrape.com/catalogue/layered-baking-building-and-styling-spectacular-cakes_904/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'availability': 'In stock',
#  'price': '£37.34',
#  'title': 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us',
#  'url': 'https://books.toscrape.com/catalogue/the-nerdy-nummies-cookbook-sweet-treats-for-the-geek-in-all-of-us_853/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'availability': 'In stock',
#  'price': '£37.60',
#  'title': 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of '
#           'Impromptu Cooking',
#  'url': 'https://books.toscrape.com/catalogue/the-love-and-lemons-cookbook-an-apple-to-zucchini-celebration-of-impromptu-cooking_849/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'availability': 'In stock',
#  'price': '£41.25',
#  'title': 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding '
#           'you to Always Eat Dessert First',
#  'url': 'https://books.toscrape.com/catalogue/the-cookies-cups-cookbook-125-sweet-savory-recipes-reminding-you-to-always-eat-dessert-first_841/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'availability': 'In stock',
#  'price': '£42.16',
#  'title': 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free '
#           'Snacks, Packed Lunches, and Simple Meals',
#  'url': 'https://books.toscrape.com/catalogue/deliciously-ella-every-day-quick-and-easy-recipes-for-gluten-free-snacks-packed-lunches-and-simple-meals_801/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'availability': 'In stock',
#  'price': '£28.77',
#  'title': 'The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes '
#           'Kids Can Make to Stay Healthy and Save the Earth',
#  'url': 'https://books.toscrape.com/catalogue/the-help-yourself-cookbook-for-kids-60-easy-plant-based-recipes-kids-can-make-to-stay-healthy-and-save-the-earth_751/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'availability': 'In stock',
#  'price': '£19.55',
#  'title': "It's All Easy: Healthy, Delicious Weeknight Meals in under 30 "
#           'Minutes',
#  'url': 'https://books.toscrape.com/catalogue/its-all-easy-healthy-delicious-weeknight-meals-in-under-30-minutes_706/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html>
#
# {'availability': 'In stock',
#  'price': '£28.01',
#  'title': 'Barefoot Contessa Back to Basics',
#  'url': 'https://books.toscrape.com/catalogue/barefoot-contessa-back-to-basics_667/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/business_35/index.html>
#
# {'availability': 'In stock',
#  'price': '£44.88',
#  'title': 'Rework',
#  'url': 'https://books.toscrape.com/catalogue/rework_212/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'availability': 'In stock',
#  'price': '£54.23',
#  'title': 'Sapiens: A Brief History of Humankind',
#  'url': 'https://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'availability': 'In stock',
#  'price': '£25.52',
#  'title': 'Unbound: How Eight Technologies Made Us Human, Transformed Society, '
#           'and Brought Our World to the Brink',
#  'url': 'https://books.toscrape.com/catalogue/unbound-how-eight-technologies-made-us-human-transformed-society-and-brought-our-world-to-the-brink_950/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'availability': 'In stock',
#  'price': '£19.73',
#  'title': 'The Age of Genius: The Seventeenth Century and the Birth of the '
#           'Modern Mind',
#  'url': 'https://books.toscrape.com/catalogue/the-age-of-genius-the-seventeenth-century-and-the-birth-of-the-modern-mind_929/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'availability': 'In stock',
#  'price': '£36.28',
#  'title': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom '
#           'Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes '
#           'in the Annals of American Politics',
#  'url': 'https://books.toscrape.com/catalogue/political-suicide-missteps-peccadilloes-bad-calls-backroom-hijinx-sordid-pasts-rotten-breaks-and-just-plain-dumb-mistakes-in-the-annals-of-american-politics_917/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'availability': 'In stock',
#  'price': '£59.64',
#  'title': 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That '
#           'Changed American History',
#  'url': 'https://books.toscrape.com/catalogue/thomas-jefferson-and-the-tripoli-pirates-the-forgotten-war-that-changed-american-history_867/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'availability': 'In stock',
#  'price': '£24.70',
#  'title': 'Zealot: The Life and Times of Jesus of Nazareth',
#  'url': 'https://books.toscrape.com/catalogue/zealot-the-life-and-times-of-jesus-of-nazareth_785/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'availability': 'In stock',
#  'price': '£14.58',
#  'title': 'A Distant Mirror: The Calamitous 14th Century',
#  'url': 'https://books.toscrape.com/catalogue/a-distant-mirror-the-calamitous-14th-century_652/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'availability': 'In stock',
#  'price': '£21.80',
#  'title': '1491: New Revelations of the Americas Before Columbus',
#  'url': 'https://books.toscrape.com/catalogue/1491-new-revelations-of-the-americas-before-columbus_650/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'availability': 'In stock',
#  'price': '£11.45',
#  'title': 'Brilliant Beacons: A History of the American Lighthouse',
#  'url': 'https://books.toscrape.com/catalogue/brilliant-beacons-a-history-of-the-american-lighthouse_515/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'availability': 'In stock',
#  'price': '£44.48',
#  'title': '"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire '
#           'of the Imagination',
#  'url': 'https://books.toscrape.com/catalogue/most-blessed-of-the-patriarchs-thomas-jefferson-and-the-empire-of-the-imagination_509/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'availability': 'In stock',
#  'price': '£52.40',
#  'title': 'A Short History of Nearly Everything',
#  'url': 'https://books.toscrape.com/catalogue/a-short-history-of-nearly-everything_457/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'availability': 'In stock',
#  'price': '£39.67',
#  'title': 'The Rise and Fall of the Third Reich: A History of Nazi Germany',
#  'url': 'https://books.toscrape.com/catalogue/the-rise-and-fall-of-the-third-reich-a-history-of-nazi-germany_454/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/history_32/index.html>
#
# {'availability': 'In stock',
#  'price': '£58.55',
#  'title': 'Catherine the Great: Portrait of a Woman',
#  'url': 'https://books.toscrape.com/catalogue/catherine-the-great-portrait-of-a-woman_424/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/health_47/index.html>
#
# {'availability': 'In stock',
#  'price': '£49.05',
#  'title': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and '
#           'Focus, Upgrade Your Life',
#  'url': 'https://books.toscrape.com/catalogue/the-bulletproof-diet-lose-up-to-a-pound-a-day-reclaim-energy-and-focus-upgrade-your-life_931/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/health_47/index.html>
#
# {'availability': 'In stock',
#  'price': '£54.07',
#  'title': 'Eat Fat, Get Thin',
#  'url': 'https://books.toscrape.com/catalogue/eat-fat-get-thin_688/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/health_47/index.html>
#
# {'availability': 'In stock',
#  'price': '£49.71',
#  'title': '10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!',
#  'url': 'https://books.toscrape.com/catalogue/10-day-green-smoothie-cleanse-lose-up-to-15-pounds-in-10-days_581/index.html'}
# 2025-11-25 16:16:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/health_47/index.html>
#
# {'availability': 'In stock',
#  'price': '£52.98',
#  'title': 'The Art and Science of Low Carbohydrate Living',
#  'url': 'https://books.toscrape.com/catalogue/the-art-and-science-of-low-carbohydrate-living_570/index.html'}
# ...
#  'title': 'Sharp Objects',
#  'url': 'https://books.toscrape.com/catalogue/sharp-objects_997/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£19.63',
#  'title': 'In a Dark, Dark Wood',
#  'url': 'https://books.toscrape.com/catalogue/in-a-dark-dark-wood_963/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£56.50',
#  'title': 'The Past Never Ends',
#  'url': 'https://books.toscrape.com/catalogue/the-past-never-ends_942/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£16.64',
#  'title': 'A Murder in Time',
#  'url': 'https://books.toscrape.com/catalogue/a-murder-in-time_877/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£44.10',
#  'title': 'The Murder of Roger Ackroyd (Hercule Poirot #4)',
#  'url': 'https://books.toscrape.com/catalogue/the-murder-of-roger-ackroyd-hercule-poirot-4_852/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£54.21',
#  'title': 'The Last Mile (Amos Decker #2)',
#  'url': 'https://books.toscrape.com/catalogue/the-last-mile-amos-decker-2_754/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£13.92',
#  'title': 'That Darkness (Gardiner and Renner #1)',
#  'url': 'https://books.toscrape.com/catalogue/that-darkness-gardiner-and-renner-1_743/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£10.69',
#  'title': 'Tastes Like Fear (DI Marnie Rome #3)',
#  'url': 'https://books.toscrape.com/catalogue/tastes-like-fear-di-marnie-rome-3_742/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'availability': 'In stock',
#  'price': '£18.97',
#  'title': 'Pop Gun War, Volume 1: Gift',
#  'url': 'https://books.toscrape.com/catalogue/pop-gun-war-volume-1-gift_918/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'availability': 'In stock',
#  'price': '£10.16',
#  'title': 'Patience',
#  'url': 'https://books.toscrape.com/catalogue/patience_916/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'availability': 'In stock',
#  'price': '£15.44',
#  'title': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)',
#  'url': 'https://books.toscrape.com/catalogue/outcast-vol-1-a-darkness-surrounds-him-outcast-1_915/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'availability': 'In stock',
#  'price': '£48.41',
#  'title': 'orange: The Complete Collection 1 (orange: The Complete Collection '
#           '#1)',
#  'url': 'https://books.toscrape.com/catalogue/orange-the-complete-collection-1-orange-the-complete-collection-1_914/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'availability': 'In stock',
#  'price': '£46.91',
#  'title': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)',
#  'url': 'https://books.toscrape.com/catalogue/lumberjanes-vol-2-friendship-to-the-max-lumberjanes-5-8_907/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'availability': 'In stock',
#  'price': '£45.61',
#  'title': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)',
#  'url': 'https://books.toscrape.com/catalogue/lumberjanes-vol-1-beware-the-kitten-holy-lumberjanes-1-4_906/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'availability': 'In stock',
#  'price': '£19.92',
#  'title': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)',
#  'url': 'https://books.toscrape.com/catalogue/lumberjanes-vol-3-a-terrible-plan-lumberjanes-9-12_905/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'availability': 'In stock',
#  'price': '£29.17',
#  'title': 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland '
#           '(Compilations) #1-5)',
#  'url': 'https://books.toscrape.com/catalogue/i-hate-fairyland-vol-1-madly-ever-after-i-hate-fairyland-compilations-1-5_899/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'availability': 'In stock',
#  'price': '£54.63',
#  'title': 'I am a Hero Omnibus Volume 1',
#  'url': 'https://books.toscrape.com/catalogue/i-am-a-hero-omnibus-volume-1_898/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'availability': 'In stock',
#  'price': '£22.11',
#  'title': 'Giant Days, Vol. 2 (Giant Days #5-8)',
#  'url': 'https://books.toscrape.com/catalogue/giant-days-vol-2-giant-days-5-8_895/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'availability': 'In stock',
#  'price': '£51.99',
#  'title': 'Danganronpa Volume 1',
#  'url': 'https://books.toscrape.com/catalogue/danganronpa-volume-1_889/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'availability': 'In stock',
#  'price': '£36.72',
#  'title': 'Codename Baboushka, Volume 1: The Conclave of Death',
#  'url': 'https://books.toscrape.com/catalogue/codename-baboushka-volume-1-the-conclave-of-death_887/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
#
# {'availability': 'In stock',
#  'price': '£17.08',
#  'title': 'Camp Midnight',
#  'url': 'https://books.toscrape.com/catalogue/camp-midnight_886/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html>
#
# {'availability': 'In stock',
#  'price': '£17.28',
#  'title': 'Lilac Girls',
#  'url': 'https://books.toscrape.com/catalogue/lilac-girls_597/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html>
#
# {'availability': 'In stock',
#  'price': '£16.62',
#  'title': 'The Constant Princess (The Tudor Court #1)',
#  'url': 'https://books.toscrape.com/catalogue/the-constant-princess-the-tudor-court-1_493/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html>
#
# {'availability': 'In stock',
#  'price': '£37.34',
#  'title': 'The Invention of Wings',
#  'url': 'https://books.toscrape.com/catalogue/the-invention-of-wings_448/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html>
#
# {'availability': 'In stock',
#  'price': '£32.97',
#  'title': 'World Without End (The Pillars of the Earth #2)',
#  'url': 'https://books.toscrape.com/catalogue/world-without-end-the-pillars-of-the-earth-2_420/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html>
#
# {'availability': 'In stock',
#  'price': '£28.32',
#  'title': 'The Passion of Dolssa',
#  'url': 'https://books.toscrape.com/catalogue/the-passion-of-dolssa_351/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html>
#
# {'availability': 'In stock',
#  'price': '£26.77',
#  'title': 'Girl With a Pearl Earring',
#  'url': 'https://books.toscrape.com/catalogue/girl-with-a-pearl-earring_322/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html>
#
# {'availability': 'In stock',
#  'price': '£21.07',
#  'title': 'Voyager (Outlander #3)',
#  'url': 'https://books.toscrape.com/catalogue/voyager-outlander-3_299/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html>
#
# {'availability': 'In stock',
#  'price': '£35.66',
#  'title': 'The Red Tent',
#  'url': 'https://books.toscrape.com/catalogue/the-red-tent_273/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html>
#
# {'availability': 'In stock',
#  'price': '£55.55',
#  'title': 'The Last Painting of Sara de Vos',
#  'url': 'https://books.toscrape.com/catalogue/the-last-painting-of-sara-de-vos_259/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html>
#
# {'availability': 'In stock',
#  'price': '£49.53',
#  'title': 'The Guernsey Literary and Potato Peel Pie Society',
#  'url': 'https://books.toscrape.com/catalogue/the-guernsey-literary-and-potato-peel-pie-society_253/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html>
#
# {'availability': 'In stock',
#  'price': '£46.83',
#  'title': 'Girl in the Blue Coat',
#  'url': 'https://books.toscrape.com/catalogue/girl-in-the-blue-coat_160/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£48.35',
#  'title': 'A Time of Torment (Charlie Parker #14)',
#  'url': 'https://books.toscrape.com/catalogue/a-time-of-torment-charlie-parker-14_657/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£16.73',
#  'title': 'A Study in Scarlet (Sherlock Holmes #1)',
#  'url': 'https://books.toscrape.com/catalogue/a-study-in-scarlet-sherlock-holmes-1_656/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£26.80',
#  'title': 'Poisonous (Max Revere Novels #3)',
#  'url': 'https://books.toscrape.com/catalogue/poisonous-max-revere-novels-3_627/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£54.36',
#  'title': 'Murder at the 42nd Street Library (Raymond Ambler #1)',
#  'url': 'https://books.toscrape.com/catalogue/murder-at-the-42nd-street-library-raymond-ambler-1_624/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£35.28',
#  'title': 'Most Wanted',
#  'url': 'https://books.toscrape.com/catalogue/most-wanted_623/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£11.84',
#  'title': 'Hide Away (Eve Duncan #20)',
#  'url': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£59.48',
#  'title': 'Boar Island (Anna Pigeon #19)',
#  'url': 'https://books.toscrape.com/catalogue/boar-island-anna-pigeon-19_613/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£27.26',
#  'title': 'The Widow',
#  'url': 'https://books.toscrape.com/catalogue/the-widow_609/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£13.71',
#  'title': 'Playing with Fire',
#  'url': 'https://books.toscrape.com/catalogue/playing-with-fire_602/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£25.37',
#  'title': 'What Happened on Beale Street (Secrets of the South Mysteries #2)',
#  'url': 'https://books.toscrape.com/catalogue/what-happened-on-beale-street-secrets-of-the-south-mysteries-2_506/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£52.30',
#  'title': "The Bachelor Girl's Guide to Murder (Herringford and Watts "
#           'Mysteries #1)',
#  'url': 'https://books.toscrape.com/catalogue/the-bachelor-girls-guide-to-murder-herringford-and-watts-mysteries-1_491/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
#
# {'availability': 'In stock',
#  'price': '£20.89',
#  'title': 'Delivering the Truth (Quaker Midwife Mystery #1)',
#  'url': 'https://books.toscrape.com/catalogue/delivering-the-truth-quaker-midwife-mystery-1_464/index.html'}
# 2025-11-25 16:16:55 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-11-25 16:16:55 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 15657,
#  'downloader/request_count': 52,
#  'downloader/request_method_count/GET': 52,
#  'downloader/response_bytes': 1858524,
#  'downloader/response_count': 52,
#  'downloader/response_status_count/200': 51,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 2.312761,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 11, 25, 15, 16, 55, 341603, tzinfo=datetime.timezone.utc),
#  'item_scraped_count': 517,
#  'log_count/DEBUG': 570,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'request_depth_max': 1,
#  'response_received_count': 52,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 51,
#  'scheduler/dequeued/memory': 51,
#  'scheduler/enqueued': 51,
#  'scheduler/enqueued/memory': 51,
#  'start_time': datetime.datetime(2025, 11, 25, 15, 16, 53, 28842, tzinfo=datetime.timezone.utc)}
# 2025-11-25 16:16:55 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## Postprocessing
#
# Si l'on se réfère au diagramme d'architecture de Scrapy, on voit qu'il
# est possible d'insérer des composants supplémentaires dans le flux de
# traitement. Ces composants s'appellent `Pipelines`.
#
# Par défaut, tous les `Item` générés au sein d'un projet Scrapy passent
# par les `Pipelines`. Les pipelines sont utilisés la plupart du temps
# pour :
#
# -   Nettoyer du contenu HTML ;
# -   Valider les données scrapées ;
# -   Supprimer les items qu'on ne souhaite pas stocker ;
# -   Stocker ces objets dans des bases de données.
#
# Les pipelines doivent être définis dans le fichier `pipelines.py`.
#
# Dans notre cas, on peut vouloir nettoyer le champ `title` pour enlever
# les caractères superflus.
#
# Nous allons alors transferer la fonction de nettoyage du code html dans
# une Pipeline.

# %%
# %load newscrawler/newscrawler/pipelines.py

# Define your item pipelines here
#
# Don't forget to add your pipeline to the ITEM_PIPELINES setting
# See: https://docs.scrapy.org/en/latest/topics/item-pipeline.html

from scrapy.exceptions import DropItem


class TextPipeline(object):

    def process_item(self, item, spider):
        if item['title']:
            item["title"] = clean_spaces(item["title"])
            return item
        else:
            raise DropItem(f"Missing title in {item}")


def clean_spaces(string):
    if string:
        return " ".join(string.split())

# %% [markdown]
# Pour dire au process Scrapy de faire transiter les items par ces
# pipelines. Il faut le spécifier dans le fichier de paramétrage
# `settings.py`.

# %%
ITEM_PIPELINES = {
    'newscrawler.pipelines.TextPipeline': 300,
}

# %% [markdown]
# On peut maintenant supprimer la fonction `clean_spaces()` de
# l'extraction des données et laisser le Pipeline faire son travail. La
# valeur entière définie permet de déterminer l'ordre dans lequel les
# pipelines vont être appelés. Ces entiers peuvent être compris entre 0 et
# 1000.
#
# On relance notre spider :
# ```
# scrapy crawl lemondev4 -o ../data/articles.json
# ```

# %% [markdown]
# On peut aussi utiliser les Pipelines pour stocker les données récupérées
# dans une base de données.
#
# La prochaine partie du cours explique plus en détail le fonctionnement de Mongo, mais voici une bref introduction
#
# Pour stocker les items dans des documents mongo :

# %%
import pymongo


class MongoPipeline(object):
    collection_name = 'scrapy_items'

    def open_spider(self, spider):
        self.client = pymongo.MongoClient()
        self.db = self.client["lemonde"]

    def close_spider(self, spider):
        self.client.close()

    def process_item(self, item, spider):
        self.db[self.collection_name].insert_one(dict(item))
        return item

# %% [markdown]
# Ici on redéfinit deux autres méthodes: `open_spider()`et
# `close_spider()`, ces méthodes sont appelées comme leur nom l'indique,
# lorsque la Spider est instanciée et fermée.
#
# Ces méthodes nous permettent d'ouvrir la connexion Mongo et de la fermer
# lorsque le scraping se termine. La méthode `process_item()` est appelé à
# chaque fois qu'un item passe dans le mécanisme interne de scrapy. Ici,
# la méthode permet d'insérer l'item en tant que document mongo.
#
# Pour que ce pipeline soit appelé il faut l'ajouter dans les settings du
# projet.

# %%
ITEM_PIPELINES = {
    'newscrawler.pipelines.TextPipeline': 100,
    'newscrawler.pipelines.MongoPipeline': 300
}

# %% [markdown]
# Le pipeline est ajoutée à la fin du process pour profiter des deux
# précédents.

# %% [markdown]
# ## Settings
#
# Scrapy permet de gérer le comportement des spiders avec certains
# paramètres. Comme expliqué dans le premier cours, il est important de
# suivre des règles en respectant la structure des différents sites. Il
# existe énormément de paramètres mais nous allons (dans le cadre de ce
# cours) aborder les plus utilisés :
#
# -   DOWNLOAD\_DELAY : Le temps de téléchargement entre chaque requête
#     sur le même domaine ;
# -   CONCURRENT\_REQUESTS\_PER\_DOMAIN : Nombre de requêtes simultanées
#     par domaine ;
# -   CONCURRENT\_REQUESTS\_PER\_IP : Nombre de requêtes simultanées par
#     IP ;
# -   DEFAULT\_REQUEST\_HEADERS : Headers HTTP utilisés pour les requêtes
#     ;
# -   ROBOTSTXT\_OBEY : Scrapy récupère le robots.txt et adapte le
#     scraping en fonction des règles trouvées ;
# -   USER\_AGENT : UserAgent utilisé pour faire les requêtes ;
# -   BOT\_NAME : Nom du bot annoncé lors des requêtes
# -   HTTPCACHE\_ENABLED : Utilisation du cache HTTP, utile lors du
#     parcours multiple de la même page.
#
# Le fichiers `settings.py` permet de définir les paramètres globaux d'un
# projet. Si votre projet contient un grand nombre de spiders, il peut
# être intéressant d'avoir des paramètres distincts pour chaque spider. Un
# moyen simple est d'ajouter un attribut `custom_settings` à votre spider
# :

# %%
class BooksSpider(scrapy.Spider):
    name = "books"
    allowed_domains = ["books.toscrape.com"]
    start_urls = ['http://books.toscrape.com/']
    custom_settings = {
        "HTTPCACHE_ENABLED": True,
        "CONCURRENT_REQUESTS_PER_DOMAIN": 100
    }

# %% [markdown]
# C'est la fin de l'introduction à Scrapy. Vous pouvez passer à la suite `3Mongo`
